# %%
args = {
    'model_name':'HP-ART',
    'FP':'float32',
    'optimizer': 'Adam', #SGD, RMSprop, Adadelta, Adagrad, Adam, Adamax, Nadam
    'dataset':'~/datasets/HP-ART/',
    'batch_size':None,
    'split_point': 0.8, #80% Training , 20% Validation
    'rnd_seed': 1234,
    'folds':5,
    'epochs_number':5,
    'image_size':64,
    'resume': False
}

clean_args = {
    'rm_na': True,
    'rm_cor': False,
    'reduce': False,
}

# %%
import time

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

from sklearn.ensemble import RandomForestRegressor, BaggingRegressor, ExtraTreesRegressor  # Ensemble methods
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from sklearn.metrics import mean_squared_error
from sklearn.svm import SVR 

from xgboost import XGBRegressor, DMatrix, plot_importance # XGBoost
from lightgbm import LGBMRegressor

# %%
# Load data and display info
df_train = pd.read_csv(args['dataset'] + 'train.csv', index_col = 0) 
df_test = pd.read_csv(args['dataset'] + 'test.csv', index_col = 0)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
null_values_per_col = np.sum(df_train.drop(["SalePrice"], axis=1).isnull(), axis=0)
#print("Null values per columns")
#print(null_values_per_col)

max_na = int(df_train.shape[0]/3.0)
cols_to_remove = []

for col in df_train.drop(["SalePrice"],axis=1).columns.tolist():
    if null_values_per_col[col] > max_na: 
        cols_to_remove.append(col)
        df_train.drop(col, axis=1, inplace=True)
        
print("New shape of the training set is: (%d,%d)" %df_train.shape)        
print("The removed columns are: " + str(cols_to_remove))

#for column in cols_to_remove:
#    print(column, "Dropped because it has %d missing values" %null_values_per_col[column])
    
#print("Dropping the same columns from the test set")    
df_test.drop(cols_to_remove, axis=1, inplace=True)

#print("New shape of the test set is: (%d,%d)" %df_test.shape)
# Out:
# New shape of the training set is: (1460,75)
# The removed columns are: ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
# reduce some known redundant features
if clean_args['reduce']:
    df_train['TotalSF'] = (df_train['BsmtFinSF1'] + df_train['BsmtFinSF2'] +
                                     df_train['1stFlrSF'] + df_train['2ndFlrSF'])

    df_train['TotalBathrooms'] = (df_train['FullBath'] + (0.5 * df_train['HalfBath']) +
                                   df_train['BsmtFullBath'] + (0.5 * df_train['BsmtHalfBath']))

    df_train['TotalPorchSF'] = (df_train['OpenPorchSF'] + df_train['3SsnPorch'] +
                                  df_train['EnclosedPorch'] + df_train['ScreenPorch'] +
                                  df_train['WoodDeckSF'])


    df_test['TotalSF'] = (df_test['BsmtFinSF1'] + df_test['BsmtFinSF2'] +
                                     df_test['1stFlrSF'] + df_test['2ndFlrSF'])

    df_test['TotalBathrooms'] = (df_test['FullBath'] + (0.5 * df_test['HalfBath']) +
                                   df_test['BsmtFullBath'] + (0.5 * df_test['BsmtHalfBath']))

    df_test['TotalPorchSF'] = (df_test['OpenPorchSF'] + df_test['3SsnPorch'] +
                                  df_test['EnclosedPorch'] + df_test['ScreenPorch'] +
                                  df_test['WoodDeckSF'])
    
    # remove the old ones
    columns_rm = ['BsmtFinSF1', 'BsmtFinSF2', '1stFlrSF', '2ndFlrSF', 'FullBath', 'HalfBath', 'BsmtFullBath',
                  'BsmtHalfBath', 'OpenPorchSF', '3SsnPorch', 'EnclosedPorch', 'ScreenPorch', 'WoodDeckSF']
    df_train = df_train.drop(columns_rm, axis=1)
    df_test = df_test.drop(columns_rm, axis=1)

# %%
rep_map_1 = {"NA": 0, "Po": 1,
             "Fa": 2, "TA": 3, 
             "Gd": 4, "Ex": 5,}

rep_map_2 = {"NA": 0, "No": 1,
             "Mn": 2, "Av": 3, 
             "Gd": 4,}

rep_map_3 = {"NA": 0, "Unf": 1,
             "LwQ": 2, "Rec": 3, 
             "BLQ": 4, "ALQ": 5,
             "GLQ": 6,}

rep_map_4 = {"NA": 0, "MnWw": 1,
             "GdWo": 2, "MnPrv": 3, 
             "GdPrv": 4,}

scale_list_1 = ["ExterCond", "BsmtCond", "HeatingQC", "KitchenQual", "GarageCond"]
scale_list_2 = ["BsmtFinType1"]
scale_list_3 = ["BsmtFinType2"]
scale_list_4 = ["Fence"]

# %%
for s in scale_list_1:
    df_train = df_train.replace({s:rep_map_1,})
    df_test = df_test.replace({s:rep_map_1,})

df_train = df_train.replace({scale_list_2[0]:rep_map_2,
                             scale_list_3[0]:rep_map_3,
                             scale_list_4[0]:rep_map_4,})

df_test = df_test.replace({scale_list_2[0]:rep_map_2,
                             scale_list_3[0]:rep_map_3,
                             scale_list_4[0]:rep_map_4,})

#df_test['GarageQual'] = df_test['GarageQual'].fillna(0)

# %%
# correlation matrix
corr_mat = df_train.drop(columns=["SalePrice"]).corr().abs()

# %%
# plot the heatmap with seaborn
plt.figure(figsize=(30,30)) 
sns.heatmap(corr_mat, 
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
# display correlation values
#corr_mat.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)

# %%
#list the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-20:-len(corr_mat)])
# Out:
# YearRemodAdd  GarageYrBlt     0.642277
# GarageYrBlt   YearRemodAdd    0.642277
# BsmtFullBath  BsmtFinSF1      0.649212
# BsmtFinSF1    BsmtFullBath    0.649212
# KitchenQual   OverallQual     0.673331
# OverallQual   KitchenQual     0.673331
# BedroomAbvGr  TotRmsAbvGrd    0.676620
# TotRmsAbvGrd  BedroomAbvGr    0.676620
# 2ndFlrSF      GrLivArea       0.687501
# GrLivArea     2ndFlrSF        0.687501
# BsmtFinSF2    BsmtFinType2    0.805212
# BsmtFinType2  BsmtFinSF2      0.805212
# TotalBsmtSF   1stFlrSF        0.819530
# 1stFlrSF      TotalBsmtSF     0.819530
# GrLivArea     TotRmsAbvGrd    0.825489
# TotRmsAbvGrd  GrLivArea       0.825489
# GarageYrBlt   YearBuilt       0.825667
# YearBuilt     GarageYrBlt     0.825667
# GarageCars    GarageArea      0.882475
# GarageArea    GarageCars      0.882475
# dtype: float64

# %%
# remove highly correlated columns if needed
if clean_args['rm_cor']:
    columns_corr = ["GarageYrBlt", "GarageCars", "GrLivArea"]
    df_train = df_train.drop(columns=columns_corr)
    df_test = df_test.drop(columns=columns_corr)

# %%
# plot all categorical
categorical_list = []

for col in df_train.columns.tolist():
    if df_train[col].dtype == 'object':
        categorical_list.append(col)
        #sns.countplot(col, data=df_train)
        #plt.xticks(rotation=55)
        #plt.show()

# %%
print(categorical_list)
# Out:
# ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'Heating', 'CentralAir', 'Electrical', 'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'PavedDrive', 'SaleType', 'SaleCondition']

# %%
# select categorical list
sel_cat_list = ["MSZoning", "LotConfig", "Neighborhood", "BldgType", "HouseStyle", "Exterior1st", "MasVnrType",
                    "Foundation", "BsmtFinType1", "SaleCondition"]

df_train = pd.get_dummies(df_train, columns=categorical_list)
df_test = pd.get_dummies(df_test, columns=categorical_list)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Columns: 251 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(5), int64(37), uint8(209)
# memory usage: 788.5 KB

# %%
# delete the other categorical columns
for col in df_train.columns.tolist():
    if df_train[col].dtype == 'object':
        del df_train[col]
        del df_test[col]
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Columns: 251 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(5), int64(37), uint8(209)
# memory usage: 788.5 KB

# %%
skewness = df_train['SalePrice'].skew()
df_train['SalePrice'].plot.hist(edgecolor='white', bins=30, 
                                label='SalePrice skew =' + str(round(skewness,2)))
plt.suptitle("SalePrice distribution")
plt.legend()
plt.show()

# %%
skewness = np.log(df_train['SalePrice']).skew()
np.log(df_train['SalePrice']).plot.hist(edgecolor='white', bins=30, 
                                label='SalePrice skew =' + str(round(skewness,2)))
plt.suptitle("SalePrice distribution")
plt.legend()
plt.show()

del skewness

# %%
train_stats = df_train.describe()
train_stats
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea    ExterCond   BsmtFinSF1  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262     3.083562   443.639726  ...
# std      30.202904     20.645407   181.066207     0.351054   456.098091  ...
# min    1872.000000   1950.000000     0.000000     1.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     3.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000     3.000000   383.500000  ...
# 75%    2000.000000   2004.000000   166.000000     3.000000   712.250000  ...
# max    2010.000000   2010.000000  1600.000000     5.000000  5644.000000  ...
#
#        SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# count     1460.000000   1460.000000   1460.000000  1460.000000
# mean         0.003425      0.083562      0.002055     0.867808
# std          0.058440      0.276824      0.045299     0.338815
# min          0.000000      0.000000      0.000000     0.000000
# 25%          0.000000      0.000000      0.000000     1.000000
# 50%          0.000000      0.000000      0.000000     1.000000
# 75%          0.000000      0.000000      0.000000     1.000000
# max          1.000000      1.000000      1.000000     1.000000
#
#        SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# count            1460.000000            1460.000000           1460.000000
# mean                0.069178               0.002740              0.008219
# std                 0.253844               0.052289              0.090317
# min                 0.000000               0.000000              0.000000
# 25%                 0.000000               0.000000              0.000000
# 50%                 0.000000               0.000000              0.000000
# 75%                 0.000000               0.000000              0.000000
# max                 1.000000               1.000000              1.000000
#
#        SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# count           1460.000000           1460.000000            1460.000000
# mean               0.013699              0.820548               0.085616
# std                0.116277              0.383862               0.279893
# min                0.000000              0.000000               0.000000
# 25%                0.000000              1.000000               0.000000
# 50%                0.000000              1.000000               0.000000
# 75%                0.000000              1.000000               0.000000
# max                1.000000              1.000000               1.000000
#
# [8 rows x 251 columns]

# %%
df_train['SalePrice'] = np.log(df_train['SalePrice'])
train_dataset = df_train.sample(frac=0.8,random_state=42)
test_dataset = df_train.drop(train_dataset.index)

train_labels = train_dataset.pop('SalePrice')
test_labels = test_dataset.pop('SalePrice')

# %%
#whole training dataset to help with normalization
df_train_tmp = df_train.drop(columns=["SalePrice"])

# %%
# normalize data
def norm(x):
    #return (x - train_stats['mean']) / train_stats['std']
    return (x - df_train_tmp.mean()) / (df_train_tmp.max() - df_train_tmp.min())

normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)
norm_sub = norm(df_test)

# %%
def model_eval():
    model = XGBRegressor(max_depth=3,
                         learning_rate=0.01,
                         n_estimators=4000,
                         verbosity = 3,
                         objective='reg:linear',
                         n_jobs=-1,
                         min_child_weight=2,
                         subsample=0.7,
                         colsample_bytree=0.65,
                         approx='gpu_hist',
                         random_state=42)
    return model

# %%
n_estimators = range(3500, 5001, 250)
max_depth = [2, 3, 4]
param_grid = dict(max_depth=max_depth, n_estimators=n_estimators)
print("number of combinations: {}".format(len(n_estimators)*len(max_depth)))
# Out:
# number of combinations: 21

# %%
model = model_eval()
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
grid_result = grid_search.fit(normed_train_data, train_labels)
# Out:
# Fitting 5 folds for each of 21 candidates, totalling 105 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   44.1s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:  9.0min finished

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.015884 using {'max_depth': 3, 'n_estimators': 4000}
# -0.016186 (0.002744) with: {'max_depth': 2, 'n_estimators': 3500}
# -0.016153 (0.002688) with: {'max_depth': 2, 'n_estimators': 3750}
# -0.016115 (0.002637) with: {'max_depth': 2, 'n_estimators': 4000}
# -0.016085 (0.002571) with: {'max_depth': 2, 'n_estimators': 4250}
# -0.016075 (0.002530) with: {'max_depth': 2, 'n_estimators': 4500}
# -0.016067 (0.002495) with: {'max_depth': 2, 'n_estimators': 4750}
# -0.016066 (0.002457) with: {'max_depth': 2, 'n_estimators': 5000}
# -0.015901 (0.002978) with: {'max_depth': 3, 'n_estimators': 3500}
# -0.015886 (0.002911) with: {'max_depth': 3, 'n_estimators': 3750}
# -0.015884 (0.002881) with: {'max_depth': 3, 'n_estimators': 4000}
# -0.015908 (0.002856) with: {'max_depth': 3, 'n_estimators': 4250}
# -0.015908 (0.002832) with: {'max_depth': 3, 'n_estimators': 4500}
# -0.015914 (0.002800) with: {'max_depth': 3, 'n_estimators': 4750}
# -0.015930 (0.002791) with: {'max_depth': 3, 'n_estimators': 5000}
# -0.016103 (0.003223) with: {'max_depth': 4, 'n_estimators': 3500}
# -0.016106 (0.003205) with: {'max_depth': 4, 'n_estimators': 3750}
# -0.016113 (0.003200) with: {'max_depth': 4, 'n_estimators': 4000}
# -0.016126 (0.003199) with: {'max_depth': 4, 'n_estimators': 4250}
# -0.016136 (0.003206) with: {'max_depth': 4, 'n_estimators': 4500}
# -0.016147 (0.003197) with: {'max_depth': 4, 'n_estimators': 4750}
# -0.016153 (0.003193) with: {'max_depth': 4, 'n_estimators': 5000}

# %%
# plot results
scores = np.array(means).reshape(len(max_depth), len(n_estimators))
for i, value in enumerate(max_depth):
    plt.plot(n_estimators, scores[i], label='depth: ' + str(value))
plt.legend()
plt.title("XGBoost n_estimators vs max_depth")
plt.xlabel('n_estimators')
plt.ylabel('MSE')
plt.savefig('n_estimators_vs_max_depth.png')

# %%
scores_1 = np.array(means).reshape(len(max_depth), len(n_estimators))
scores_2 = np.array(stds).reshape(len(max_depth), len(n_estimators))

plt.errorbar(n_estimators, scores_1[1], yerr=scores_2[1])
plt.title("XGBoost n_estimators vs -MSE")
plt.xlabel('n_estimators')
plt.ylabel('MSE')
plt.savefig('n_estimators_vs_mse_{}.png'.format(max_depth[1]))

# %%
n_estimators = range(3750, 4251, 250)
max_depth = [3]
min_child_weight = range(0, 4, 1)
param_grid = dict(max_depth=max_depth, n_estimators=n_estimators, min_child_weight=min_child_weight)
print("number of combinations: {}".format(len(n_estimators)*len(max_depth)*len(min_child_weight)))
# Out:
# number of combinations: 12

# %%
model = model_eval()
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
grid_result = grid_search.fit(normed_train_data, train_labels)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:   55.9s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  5.4min finished

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.015818 using {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 4000}
# -0.015886 (0.002911) with: {'max_depth': 3, 'min_child_weight': 0, 'n_estimators': 3750}
# -0.015884 (0.002881) with: {'max_depth': 3, 'min_child_weight': 0, 'n_estimators': 4000}
# -0.015908 (0.002856) with: {'max_depth': 3, 'min_child_weight': 0, 'n_estimators': 4250}
# -0.015886 (0.002911) with: {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 3750}
# -0.015884 (0.002881) with: {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 4000}
# -0.015908 (0.002856) with: {'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 4250}
# -0.015840 (0.002316) with: {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 3750}
# -0.015818 (0.002279) with: {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 4000}
# -0.015823 (0.002260) with: {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 4250}
# -0.016046 (0.002304) with: {'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 3750}
# -0.016041 (0.002254) with: {'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 4000}
# -0.016056 (0.002219) with: {'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 4250}

# %%
gamma = np.arange(0.0000, 0.00001, 0.00002)
reg_alpha = np.arange(0.00004, 0.00005, 0.00002)
reg_lambda= np.arange(0.99984, 0.9999, 0.00002)

param_grid = dict(gamma = gamma, reg_alpha=reg_alpha, reg_lambda=reg_lambda)
print("number of combinations: {}".format(len(gamma)*len(reg_alpha)*len(reg_lambda)))
# Out:
# number of combinations: 4

# %%
model = model_eval()
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
grid_result = grid_search.fit(normed_train_data, train_labels)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  20 | elapsed:   54.2s remaining:   36.1s
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  1.2min finished

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.015859 using {'gamma': 0.0, 'reg_alpha': 4e-05, 'reg_lambda': 0.99988}
# -0.015868 (0.002255) with: {'gamma': 0.0, 'reg_alpha': 4e-05, 'reg_lambda': 0.99984}
# -0.015866 (0.002263) with: {'gamma': 0.0, 'reg_alpha': 4e-05, 'reg_lambda': 0.99986}
# -0.015859 (0.002264) with: {'gamma': 0.0, 'reg_alpha': 4e-05, 'reg_lambda': 0.99988}
# -0.015868 (0.002252) with: {'gamma': 0.0, 'reg_alpha': 4e-05, 'reg_lambda': 0.9999}

# %%
model = XGBRegressor(max_depth=3,
                     learning_rate=0.01,
                     n_estimators=4000, #3460
                     verbosity = 3,
                     objective='reg:linear',
                     n_jobs=-1,
                     gamma=0, #dflt: 0
                     min_child_weight=2, #dflt: 0
                     subsample=0.7,
                     colsample_bytree=0.5,
                     reg_lambda=0.99986, #1 dflt: 1
                     reg_alpha=0.00004, #0.00006 dflt: 0
                     tree_method='gpu_hist',
                     scale_pos_weight=1, # dflt: 1
                     random_state=42)

# %%
tick=time.time()

fitted_model = model.fit(
    normed_train_data, train_labels,
    eval_set=[(normed_test_data, test_labels)],
    eval_metric='rmse',
    early_stopping_rounds=100,
    verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [0]	validation_0-rmse:11.423
# Will train until validation_0-rmse hasn't improved in 100 rounds.
# [1]	validation_0-rmse:11.3091
# [2]	validation_0-rmse:11.1962
# [3]	validation_0-rmse:11.0846
# [4]	validation_0-rmse:10.9741
# [5]	validation_0-rmse:10.8647
# [6]	validation_0-rmse:10.7564
# [7]	validation_0-rmse:10.6492
# [8]	validation_0-rmse:10.5429
# [9]	validation_0-rmse:10.4376
# [10]	validation_0-rmse:10.3336
# [11]	validation_0-rmse:10.2305
# [12]	validation_0-rmse:10.1286
# [13]	validation_0-rmse:10.0277
# [14]	validation_0-rmse:9.92781
# [15]	validation_0-rmse:9.82873
# [16]	validation_0-rmse:9.73079
# [17]	validation_0-rmse:9.63386
# [18]	validation_0-rmse:9.53783
# [19]	validation_0-rmse:9.44271
# [20]	validation_0-rmse:9.34855
# [21]	validation_0-rmse:9.25558
# [22]	validation_0-rmse:9.16356
# [23]	validation_0-rmse:9.07234
# [24]	validation_0-rmse:8.98201
# [25]	validation_0-rmse:8.89256
# [26]	validation_0-rmse:8.80387
# [27]	validation_0-rmse:8.71618
# [28]	validation_0-rmse:8.62926
# [29]	validation_0-rmse:8.54324
# [30]	validation_0-rmse:8.45806
# [31]	validation_0-rmse:8.37374
# [32]	validation_0-rmse:8.29038
# [33]	validation_0-rmse:8.20781
# [34]	validation_0-rmse:8.12614
# [35]	validation_0-rmse:8.04534
# [36]	validation_0-rmse:7.96534
# [37]	validation_0-rmse:7.8862
# [38]	validation_0-rmse:7.80788
# [39]	validation_0-rmse:7.73028
# [40]	validation_0-rmse:7.6534
# [41]	validation_0-rmse:7.57719
# [42]	validation_0-rmse:7.5019
# [43]	validation_0-rmse:7.42717
# [44]	validation_0-rmse:7.35325
# [45]	validation_0-rmse:7.28013
# [46]	validation_0-rmse:7.20774
# [47]	validation_0-rmse:7.13586
# [48]	validation_0-rmse:7.0649
# [49]	validation_0-rmse:6.9946
# [50]	validation_0-rmse:6.9249
# [51]	validation_0-rmse:6.85606
# [52]	validation_0-rmse:6.78788
# [53]	validation_0-rmse:6.72034
# [54]	validation_0-rmse:6.65342
# [55]	validation_0-rmse:6.5874
# [56]	validation_0-rmse:6.52203
# [57]	validation_0-rmse:6.45726
# [58]	validation_0-rmse:6.39306
# [59]	validation_0-rmse:6.32951
# [60]	validation_0-rmse:6.26652
# [61]	validation_0-rmse:6.20431
# [62]	validation_0-rmse:6.1428
# [63]	validation_0-rmse:6.08172
# [64]	validation_0-rmse:6.02123
# [65]	validation_0-rmse:5.9616
# [66]	validation_0-rmse:5.90217
# [67]	validation_0-rmse:5.8436
# [68]	validation_0-rmse:5.78559
# [69]	validation_0-rmse:5.72811
# [70]	validation_0-rmse:5.67117
# [71]	validation_0-rmse:5.61478
# [72]	validation_0-rmse:5.55892
# [73]	validation_0-rmse:5.50363
# [74]	validation_0-rmse:5.44896
# [75]	validation_0-rmse:5.39495
# [76]	validation_0-rmse:5.34134
# [77]	validation_0-rmse:5.28823
# [78]	validation_0-rmse:5.23558
# [79]	validation_0-rmse:5.18354
# [80]	validation_0-rmse:5.13192
# [81]	validation_0-rmse:5.08094
# [82]	validation_0-rmse:5.03037
# [83]	validation_0-rmse:4.98045
# [84]	validation_0-rmse:4.93094
# [85]	validation_0-rmse:4.88213
# [86]	validation_0-rmse:4.83342
# [87]	validation_0-rmse:4.78543
# [88]	validation_0-rmse:4.73796
# [89]	validation_0-rmse:4.69073
# [90]	validation_0-rmse:4.64428
# [91]	validation_0-rmse:4.59805
# [92]	validation_0-rmse:4.55226
# [93]	validation_0-rmse:4.50721
# [94]	validation_0-rmse:4.46247
# [95]	validation_0-rmse:4.41824
# [96]	validation_0-rmse:4.37434
# [97]	validation_0-rmse:4.33086
# [98]	validation_0-rmse:4.28792
# [99]	validation_0-rmse:4.24528
# [100]	validation_0-rmse:4.20323
# [101]	validation_0-rmse:4.16145
# [102]	validation_0-rmse:4.12024
# [103]	validation_0-rmse:4.07926
# [104]	validation_0-rmse:4.03888
# [105]	validation_0-rmse:3.99897
# [106]	validation_0-rmse:3.95934
# [107]	validation_0-rmse:3.92011
# [108]	validation_0-rmse:3.88115
# [109]	validation_0-rmse:3.84241
# [110]	validation_0-rmse:3.80422
# [111]	validation_0-rmse:3.76657
# [112]	validation_0-rmse:3.72929
# [113]	validation_0-rmse:3.69227
# [114]	validation_0-rmse:3.65574
# [115]	validation_0-rmse:3.61952
# [116]	validation_0-rmse:3.58368
# [117]	validation_0-rmse:3.54827
# [118]	validation_0-rmse:3.51319
# [119]	validation_0-rmse:3.47808
# [120]	validation_0-rmse:3.44346
# [121]	validation_0-rmse:3.40954
# [122]	validation_0-rmse:3.37577
# [123]	validation_0-rmse:3.34219
# [124]	validation_0-rmse:3.30895
# [125]	validation_0-rmse:3.2762
# [126]	validation_0-rmse:3.24375
# [127]	validation_0-rmse:3.21148
# [128]	validation_0-rmse:3.17969
# [129]	validation_0-rmse:3.14823
# [130]	validation_0-rmse:3.11714
# [131]	validation_0-rmse:3.08628
# [132]	validation_0-rmse:3.05578
# [133]	validation_0-rmse:3.02556
# [134]	validation_0-rmse:2.99569
# [135]	validation_0-rmse:2.96609
# [136]	validation_0-rmse:2.9366
# [137]	validation_0-rmse:2.90748
# [138]	validation_0-rmse:2.87886
# [139]	validation_0-rmse:2.85045
# [140]	validation_0-rmse:2.82227
# [141]	validation_0-rmse:2.79429
# [142]	validation_0-rmse:2.76665
# [143]	validation_0-rmse:2.73929
# [144]	validation_0-rmse:2.71224
# [145]	validation_0-rmse:2.68539
# [146]	validation_0-rmse:2.65884
# [147]	validation_0-rmse:2.63264
# [148]	validation_0-rmse:2.60667
# [149]	validation_0-rmse:2.5809
# [150]	validation_0-rmse:2.55528
# [151]	validation_0-rmse:2.52996
# [152]	validation_0-rmse:2.50507
# [153]	validation_0-rmse:2.48029
# [154]	validation_0-rmse:2.45573
# [155]	validation_0-rmse:2.43147
# [156]	validation_0-rmse:2.4074
# [157]	validation_0-rmse:2.38344
# [158]	validation_0-rmse:2.35997
# [159]	validation_0-rmse:2.33669
# [160]	validation_0-rmse:2.31349
# [161]	validation_0-rmse:2.29057
# [162]	validation_0-rmse:2.26803
# [163]	validation_0-rmse:2.24568
# [164]	validation_0-rmse:2.22353
# [165]	validation_0-rmse:2.2017
# [166]	validation_0-rmse:2.17994
# [167]	validation_0-rmse:2.1586
# [168]	validation_0-rmse:2.13728
# [169]	validation_0-rmse:2.11615
# [170]	validation_0-rmse:2.09537
# [171]	validation_0-rmse:2.07475
# [172]	validation_0-rmse:2.05434
# [173]	validation_0-rmse:2.03409
# [174]	validation_0-rmse:2.01399
# [175]	validation_0-rmse:1.99415
# [176]	validation_0-rmse:1.97446
# [177]	validation_0-rmse:1.95503
# [178]	validation_0-rmse:1.93583
# [179]	validation_0-rmse:1.91675
# [180]	validation_0-rmse:1.898
# [181]	validation_0-rmse:1.87929
# [182]	validation_0-rmse:1.86082
# [183]	validation_0-rmse:1.84248
# [184]	validation_0-rmse:1.8243
# [185]	validation_0-rmse:1.80646
# [186]	validation_0-rmse:1.78869
# [187]	validation_0-rmse:1.77101
# [188]	validation_0-rmse:1.7536
# [189]	validation_0-rmse:1.73648
# [190]	validation_0-rmse:1.71933
# [191]	validation_0-rmse:1.70249
# [192]	validation_0-rmse:1.68576
# [193]	validation_0-rmse:1.66925
# [194]	validation_0-rmse:1.65289
# [195]	validation_0-rmse:1.63666
# [196]	validation_0-rmse:1.62072
# [197]	validation_0-rmse:1.60483
# [198]	validation_0-rmse:1.58912
# [199]	validation_0-rmse:1.5735
# [200]	validation_0-rmse:1.55811
# [201]	validation_0-rmse:1.54285
# [202]	validation_0-rmse:1.52765
# [203]	validation_0-rmse:1.51265
# [204]	validation_0-rmse:1.49792
# [205]	validation_0-rmse:1.48341
# [206]	validation_0-rmse:1.46891
# [207]	validation_0-rmse:1.4545
# [208]	validation_0-rmse:1.44015
# [209]	validation_0-rmse:1.42606
# [210]	validation_0-rmse:1.41235
# [211]	validation_0-rmse:1.39843
# [212]	validation_0-rmse:1.38491
# [213]	validation_0-rmse:1.37133
# [214]	validation_0-rmse:1.35787
# [215]	validation_0-rmse:1.34456
# [216]	validation_0-rmse:1.3314
# [217]	validation_0-rmse:1.31841
# [218]	validation_0-rmse:1.30556
# [219]	validation_0-rmse:1.29274
# [220]	validation_0-rmse:1.28017
# [221]	validation_0-rmse:1.26779
# [222]	validation_0-rmse:1.25539
# [223]	validation_0-rmse:1.24318
# [224]	validation_0-rmse:1.23095
# [225]	validation_0-rmse:1.21901
# [226]	validation_0-rmse:1.20712
# [227]	validation_0-rmse:1.19532
# [228]	validation_0-rmse:1.18367
# [229]	validation_0-rmse:1.17216
# [230]	validation_0-rmse:1.16071
# [231]	validation_0-rmse:1.1494
# [232]	validation_0-rmse:1.13821
# [233]	validation_0-rmse:1.12722
# [234]	validation_0-rmse:1.11642
# [235]	validation_0-rmse:1.10562
# [236]	validation_0-rmse:1.09498
# [237]	validation_0-rmse:1.08446
# [238]	validation_0-rmse:1.07399
# [239]	validation_0-rmse:1.06367
# [240]	validation_0-rmse:1.05329
# [241]	validation_0-rmse:1.04315
# [242]	validation_0-rmse:1.033
# [243]	validation_0-rmse:1.02294
# [244]	validation_0-rmse:1.01294
# [245]	validation_0-rmse:1.00316
# [246]	validation_0-rmse:0.993557
# [247]	validation_0-rmse:0.984006
# [248]	validation_0-rmse:0.974578
# [249]	validation_0-rmse:0.965226
# [250]	validation_0-rmse:0.955971
# [251]	validation_0-rmse:0.946906
# [252]	validation_0-rmse:0.937675
# [253]	validation_0-rmse:0.928685
# [254]	validation_0-rmse:0.919833
# [255]	validation_0-rmse:0.911001
# [256]	validation_0-rmse:0.902275
# [257]	validation_0-rmse:0.893674
# [258]	validation_0-rmse:0.885129
# [259]	validation_0-rmse:0.876548
# [260]	validation_0-rmse:0.868151
# [261]	validation_0-rmse:0.859862
# [262]	validation_0-rmse:0.851669
# [263]	validation_0-rmse:0.843514
# [264]	validation_0-rmse:0.835471
# [265]	validation_0-rmse:0.827411
# [266]	validation_0-rmse:0.819593
# [267]	validation_0-rmse:0.811804
# [268]	validation_0-rmse:0.80402
# [269]	validation_0-rmse:0.796259
# [270]	validation_0-rmse:0.788662
# [271]	validation_0-rmse:0.78124
# [272]	validation_0-rmse:0.773964
# [273]	validation_0-rmse:0.766638
# [274]	validation_0-rmse:0.759445
# [275]	validation_0-rmse:0.752141
# [276]	validation_0-rmse:0.74505
# [277]	validation_0-rmse:0.738015
# [278]	validation_0-rmse:0.731041
# [279]	validation_0-rmse:0.724131
# [280]	validation_0-rmse:0.717337
# [281]	validation_0-rmse:0.710451
# [282]	validation_0-rmse:0.703799
# [283]	validation_0-rmse:0.697176
# [284]	validation_0-rmse:0.690543
# [285]	validation_0-rmse:0.684019
# [286]	validation_0-rmse:0.677576
# [287]	validation_0-rmse:0.67124
# [288]	validation_0-rmse:0.664916
# [289]	validation_0-rmse:0.658706
# [290]	validation_0-rmse:0.652521
# [291]	validation_0-rmse:0.646428
# [292]	validation_0-rmse:0.640373
# [293]	validation_0-rmse:0.634408
# [294]	validation_0-rmse:0.628459
# [295]	validation_0-rmse:0.622683
# [296]	validation_0-rmse:0.616902
# [297]	validation_0-rmse:0.611138
# [298]	validation_0-rmse:0.605498
# [299]	validation_0-rmse:0.599867
# [300]	validation_0-rmse:0.594278
# [301]	validation_0-rmse:0.588706
# [302]	validation_0-rmse:0.583293
# [303]	validation_0-rmse:0.577942
# [304]	validation_0-rmse:0.572637
# [305]	validation_0-rmse:0.567383
# [306]	validation_0-rmse:0.562173
# [307]	validation_0-rmse:0.556996
# [308]	validation_0-rmse:0.551877
# [309]	validation_0-rmse:0.546865
# [310]	validation_0-rmse:0.541823
# [311]	validation_0-rmse:0.536925
# [312]	validation_0-rmse:0.532021
# [313]	validation_0-rmse:0.527241
# [314]	validation_0-rmse:0.522424
# [315]	validation_0-rmse:0.517739
# [316]	validation_0-rmse:0.51306
# [317]	validation_0-rmse:0.508378
# [318]	validation_0-rmse:0.503789
# [319]	validation_0-rmse:0.499222
# [320]	validation_0-rmse:0.494833
# [321]	validation_0-rmse:0.490298
# [322]	validation_0-rmse:0.485812
# [323]	validation_0-rmse:0.481411
# [324]	validation_0-rmse:0.477139
# [325]	validation_0-rmse:0.472813
# [326]	validation_0-rmse:0.468673
# [327]	validation_0-rmse:0.464445
# [328]	validation_0-rmse:0.460304
# [329]	validation_0-rmse:0.456212
# [330]	validation_0-rmse:0.45214
# [331]	validation_0-rmse:0.448159
# [332]	validation_0-rmse:0.44425
# [333]	validation_0-rmse:0.4403
# [334]	validation_0-rmse:0.436371
# [335]	validation_0-rmse:0.432523
# [336]	validation_0-rmse:0.428729
# [337]	validation_0-rmse:0.425051
# [338]	validation_0-rmse:0.421358
# [339]	validation_0-rmse:0.417683
# [340]	validation_0-rmse:0.414062
# [341]	validation_0-rmse:0.410418
# [342]	validation_0-rmse:0.406837
# [343]	validation_0-rmse:0.403296
# [344]	validation_0-rmse:0.39988
# [345]	validation_0-rmse:0.396416
# [346]	validation_0-rmse:0.392931
# [347]	validation_0-rmse:0.389452
# [348]	validation_0-rmse:0.386092
# [349]	validation_0-rmse:0.382824
# [350]	validation_0-rmse:0.379528
# [351]	validation_0-rmse:0.376269
# [352]	validation_0-rmse:0.373059
# [353]	validation_0-rmse:0.369878
# [354]	validation_0-rmse:0.366704
# [355]	validation_0-rmse:0.363574
# [356]	validation_0-rmse:0.360488
# [357]	validation_0-rmse:0.357509
# [358]	validation_0-rmse:0.354521
# [359]	validation_0-rmse:0.351613
# [360]	validation_0-rmse:0.348648
# [361]	validation_0-rmse:0.345761
# [362]	validation_0-rmse:0.342859
# [363]	validation_0-rmse:0.34
# [364]	validation_0-rmse:0.33717
# [365]	validation_0-rmse:0.334368
# [366]	validation_0-rmse:0.331631
# [367]	validation_0-rmse:0.328945
# [368]	validation_0-rmse:0.326312
# [369]	validation_0-rmse:0.323706
# [370]	validation_0-rmse:0.32108
# [371]	validation_0-rmse:0.318442
# [372]	validation_0-rmse:0.315842
# [373]	validation_0-rmse:0.313268
# [374]	validation_0-rmse:0.310704
# [375]	validation_0-rmse:0.308208
# [376]	validation_0-rmse:0.305732
# [377]	validation_0-rmse:0.303252
# [378]	validation_0-rmse:0.300826
# [379]	validation_0-rmse:0.298418
# [380]	validation_0-rmse:0.296115
# [381]	validation_0-rmse:0.293747
# [382]	validation_0-rmse:0.291414
# [383]	validation_0-rmse:0.289214
# [384]	validation_0-rmse:0.28702
# [385]	validation_0-rmse:0.284869
# [386]	validation_0-rmse:0.282669
# [387]	validation_0-rmse:0.28056
# [388]	validation_0-rmse:0.278436
# [389]	validation_0-rmse:0.276322
# [390]	validation_0-rmse:0.274246
# [391]	validation_0-rmse:0.27216
# [392]	validation_0-rmse:0.270088
# [393]	validation_0-rmse:0.268061
# [394]	validation_0-rmse:0.266122
# [395]	validation_0-rmse:0.264094
# [396]	validation_0-rmse:0.262104
# [397]	validation_0-rmse:0.260218
# [398]	validation_0-rmse:0.258326
# [399]	validation_0-rmse:0.256487
# [400]	validation_0-rmse:0.254619
# [401]	validation_0-rmse:0.252798
# [402]	validation_0-rmse:0.251003
# [403]	validation_0-rmse:0.249232
# [404]	validation_0-rmse:0.247502
# [405]	validation_0-rmse:0.245689
# [406]	validation_0-rmse:0.243973
# [407]	validation_0-rmse:0.2423
# [408]	validation_0-rmse:0.240601
# [409]	validation_0-rmse:0.238961
# [410]	validation_0-rmse:0.237275
# [411]	validation_0-rmse:0.235607
# [412]	validation_0-rmse:0.233985
# [413]	validation_0-rmse:0.232451
# [414]	validation_0-rmse:0.230854
# [415]	validation_0-rmse:0.229308
# [416]	validation_0-rmse:0.227812
# [417]	validation_0-rmse:0.226226
# [418]	validation_0-rmse:0.224707
# [419]	validation_0-rmse:0.223235
# [420]	validation_0-rmse:0.22179
# [421]	validation_0-rmse:0.220342
# [422]	validation_0-rmse:0.219001
# [423]	validation_0-rmse:0.217645
# [424]	validation_0-rmse:0.216233
# [425]	validation_0-rmse:0.214853
# [426]	validation_0-rmse:0.213514
# [427]	validation_0-rmse:0.212178
# [428]	validation_0-rmse:0.210878
# [429]	validation_0-rmse:0.209554
# [430]	validation_0-rmse:0.208225
# [431]	validation_0-rmse:0.207001
# [432]	validation_0-rmse:0.205768
# [433]	validation_0-rmse:0.20449
# [434]	validation_0-rmse:0.203241
# [435]	validation_0-rmse:0.202054
# [436]	validation_0-rmse:0.200808
# [437]	validation_0-rmse:0.199626
# [438]	validation_0-rmse:0.198425
# [439]	validation_0-rmse:0.197275
# [440]	validation_0-rmse:0.196172
# [441]	validation_0-rmse:0.195068
# [442]	validation_0-rmse:0.193949
# [443]	validation_0-rmse:0.19285
# [444]	validation_0-rmse:0.19184
# [445]	validation_0-rmse:0.190768
# [446]	validation_0-rmse:0.189707
# [447]	validation_0-rmse:0.188716
# [448]	validation_0-rmse:0.187698
# [449]	validation_0-rmse:0.18665
# [450]	validation_0-rmse:0.18565
# [451]	validation_0-rmse:0.184672
# [452]	validation_0-rmse:0.183766
# [453]	validation_0-rmse:0.182851
# [454]	validation_0-rmse:0.181873
# [455]	validation_0-rmse:0.18093
# [456]	validation_0-rmse:0.180039
# [457]	validation_0-rmse:0.179123
# [458]	validation_0-rmse:0.178287
# [459]	validation_0-rmse:0.177417
# [460]	validation_0-rmse:0.176541
# [461]	validation_0-rmse:0.175648
# [462]	validation_0-rmse:0.174872
# [463]	validation_0-rmse:0.174016
# [464]	validation_0-rmse:0.173214
# [465]	validation_0-rmse:0.17242
# [466]	validation_0-rmse:0.171638
# [467]	validation_0-rmse:0.170861
# [468]	validation_0-rmse:0.170146
# [469]	validation_0-rmse:0.169416
# [470]	validation_0-rmse:0.168682
# [471]	validation_0-rmse:0.167914
# [472]	validation_0-rmse:0.167183
# [473]	validation_0-rmse:0.166475
# [474]	validation_0-rmse:0.165687
# [475]	validation_0-rmse:0.164947
# [476]	validation_0-rmse:0.16428
# [477]	validation_0-rmse:0.163552
# [478]	validation_0-rmse:0.162896
# [479]	validation_0-rmse:0.162293
# [480]	validation_0-rmse:0.16168
# [481]	validation_0-rmse:0.161043
# [482]	validation_0-rmse:0.160393
# [483]	validation_0-rmse:0.15976
# [484]	validation_0-rmse:0.159104
# [485]	validation_0-rmse:0.158514
# [486]	validation_0-rmse:0.157863
# [487]	validation_0-rmse:0.157301
# [488]	validation_0-rmse:0.156767
# [489]	validation_0-rmse:0.156199
# [490]	validation_0-rmse:0.155634
# [491]	validation_0-rmse:0.15507
# [492]	validation_0-rmse:0.15452
# [493]	validation_0-rmse:0.153991
# [494]	validation_0-rmse:0.153415
# [495]	validation_0-rmse:0.152852
# [496]	validation_0-rmse:0.152299
# [497]	validation_0-rmse:0.151798
# [498]	validation_0-rmse:0.151318
# [499]	validation_0-rmse:0.150824
# [500]	validation_0-rmse:0.1503
# [501]	validation_0-rmse:0.149823
# [502]	validation_0-rmse:0.149355
# [503]	validation_0-rmse:0.148844
# [504]	validation_0-rmse:0.148367
# [505]	validation_0-rmse:0.147911
# [506]	validation_0-rmse:0.147474
# [507]	validation_0-rmse:0.147001
# [508]	validation_0-rmse:0.146589
# [509]	validation_0-rmse:0.146134
# [510]	validation_0-rmse:0.145665
# [511]	validation_0-rmse:0.145257
# [512]	validation_0-rmse:0.144774
# [513]	validation_0-rmse:0.144313
# [514]	validation_0-rmse:0.143879
# [515]	validation_0-rmse:0.143408
# [516]	validation_0-rmse:0.14299
# [517]	validation_0-rmse:0.142645
# [518]	validation_0-rmse:0.142261
# [519]	validation_0-rmse:0.141862
# [520]	validation_0-rmse:0.141486
# [521]	validation_0-rmse:0.141129
# [522]	validation_0-rmse:0.140706
# [523]	validation_0-rmse:0.140342
# [524]	validation_0-rmse:0.139998
# [525]	validation_0-rmse:0.13968
# [526]	validation_0-rmse:0.139343
# [527]	validation_0-rmse:0.139003
# [528]	validation_0-rmse:0.138708
# [529]	validation_0-rmse:0.138402
# [530]	validation_0-rmse:0.138089
# [531]	validation_0-rmse:0.137779
# [532]	validation_0-rmse:0.137471
# [533]	validation_0-rmse:0.137213
# [534]	validation_0-rmse:0.136904
# [535]	validation_0-rmse:0.136538
# [536]	validation_0-rmse:0.136281
# [537]	validation_0-rmse:0.135983
# [538]	validation_0-rmse:0.135651
# [539]	validation_0-rmse:0.135369
# [540]	validation_0-rmse:0.135095
# [541]	validation_0-rmse:0.134775
# [542]	validation_0-rmse:0.134549
# [543]	validation_0-rmse:0.13429
# [544]	validation_0-rmse:0.133962
# [545]	validation_0-rmse:0.133657
# [546]	validation_0-rmse:0.133408
# [547]	validation_0-rmse:0.13321
# [548]	validation_0-rmse:0.133014
# [549]	validation_0-rmse:0.132757
# [550]	validation_0-rmse:0.132493
# [551]	validation_0-rmse:0.132235
# [552]	validation_0-rmse:0.131976
# [553]	validation_0-rmse:0.131717
# [554]	validation_0-rmse:0.131516
# [555]	validation_0-rmse:0.131265
# [556]	validation_0-rmse:0.131018
# [557]	validation_0-rmse:0.130807
# [558]	validation_0-rmse:0.130607
# [559]	validation_0-rmse:0.130398
# [560]	validation_0-rmse:0.130185
# [561]	validation_0-rmse:0.129932
# [562]	validation_0-rmse:0.129735
# [563]	validation_0-rmse:0.129483
# [564]	validation_0-rmse:0.129297
# [565]	validation_0-rmse:0.129134
# [566]	validation_0-rmse:0.128955
# [567]	validation_0-rmse:0.12881
# [568]	validation_0-rmse:0.128606
# [569]	validation_0-rmse:0.128377
# [570]	validation_0-rmse:0.128226
# [571]	validation_0-rmse:0.128075
# [572]	validation_0-rmse:0.127902
# [573]	validation_0-rmse:0.12771
# [574]	validation_0-rmse:0.127547
# [575]	validation_0-rmse:0.127393
# [576]	validation_0-rmse:0.127219
# [577]	validation_0-rmse:0.127012
# [578]	validation_0-rmse:0.12679
# [579]	validation_0-rmse:0.12661
# [580]	validation_0-rmse:0.126441
# [581]	validation_0-rmse:0.126271
# [582]	validation_0-rmse:0.126102
# [583]	validation_0-rmse:0.125971
# [584]	validation_0-rmse:0.125821
# [585]	validation_0-rmse:0.125655
# [586]	validation_0-rmse:0.125524
# [587]	validation_0-rmse:0.125349
# [588]	validation_0-rmse:0.125226
# [589]	validation_0-rmse:0.125072
# [590]	validation_0-rmse:0.124943
# [591]	validation_0-rmse:0.124782
# [592]	validation_0-rmse:0.124678
# [593]	validation_0-rmse:0.124531
# [594]	validation_0-rmse:0.124368
# [595]	validation_0-rmse:0.124226
# [596]	validation_0-rmse:0.124076
# [597]	validation_0-rmse:0.123907
# [598]	validation_0-rmse:0.123784
# [599]	validation_0-rmse:0.123653
# [600]	validation_0-rmse:0.123541
# [601]	validation_0-rmse:0.123431
# [602]	validation_0-rmse:0.123266
# [603]	validation_0-rmse:0.123133
# [604]	validation_0-rmse:0.123019
# [605]	validation_0-rmse:0.122887
# [606]	validation_0-rmse:0.122786
# [607]	validation_0-rmse:0.122662
# [608]	validation_0-rmse:0.122522
# [609]	validation_0-rmse:0.122368
# [610]	validation_0-rmse:0.122253
# [611]	validation_0-rmse:0.122133
# [612]	validation_0-rmse:0.122041
# [613]	validation_0-rmse:0.121942
# [614]	validation_0-rmse:0.12178
# [615]	validation_0-rmse:0.121697
# [616]	validation_0-rmse:0.121569
# [617]	validation_0-rmse:0.121402
# [618]	validation_0-rmse:0.121304
# [619]	validation_0-rmse:0.121248
# [620]	validation_0-rmse:0.121159
# [621]	validation_0-rmse:0.12105
# [622]	validation_0-rmse:0.120923
# [623]	validation_0-rmse:0.120827
# [624]	validation_0-rmse:0.120743
# [625]	validation_0-rmse:0.12069
# [626]	validation_0-rmse:0.120573
# [627]	validation_0-rmse:0.12049
# [628]	validation_0-rmse:0.120426
# [629]	validation_0-rmse:0.120363
# [630]	validation_0-rmse:0.120233
# [631]	validation_0-rmse:0.120154
# [632]	validation_0-rmse:0.120104
# [633]	validation_0-rmse:0.119973
# [634]	validation_0-rmse:0.119908
# [635]	validation_0-rmse:0.119848
# [636]	validation_0-rmse:0.119784
# [637]	validation_0-rmse:0.119704
# [638]	validation_0-rmse:0.119626
# [639]	validation_0-rmse:0.119492
# [640]	validation_0-rmse:0.119439
# [641]	validation_0-rmse:0.119386
# [642]	validation_0-rmse:0.119345
# [643]	validation_0-rmse:0.119294
# [644]	validation_0-rmse:0.119233
# [645]	validation_0-rmse:0.119188
# [646]	validation_0-rmse:0.119136
# [647]	validation_0-rmse:0.119031
# [648]	validation_0-rmse:0.118959
# [649]	validation_0-rmse:0.118894
# [650]	validation_0-rmse:0.118831
# [651]	validation_0-rmse:0.118764
# [652]	validation_0-rmse:0.118689
# [653]	validation_0-rmse:0.118634
# [654]	validation_0-rmse:0.118603
# [655]	validation_0-rmse:0.118557
# [656]	validation_0-rmse:0.118444
# [657]	validation_0-rmse:0.118379
# [658]	validation_0-rmse:0.118315
# [659]	validation_0-rmse:0.118196
# [660]	validation_0-rmse:0.11814
# [661]	validation_0-rmse:0.118093
# [662]	validation_0-rmse:0.118074
# [663]	validation_0-rmse:0.117961
# [664]	validation_0-rmse:0.117893
# [665]	validation_0-rmse:0.117813
# [666]	validation_0-rmse:0.117725
# [667]	validation_0-rmse:0.117701
# [668]	validation_0-rmse:0.117679
# [669]	validation_0-rmse:0.117611
# [670]	validation_0-rmse:0.117581
# [671]	validation_0-rmse:0.117452
# [672]	validation_0-rmse:0.117433
# [673]	validation_0-rmse:0.117424
# [674]	validation_0-rmse:0.117384
# [675]	validation_0-rmse:0.117329
# [676]	validation_0-rmse:0.117262
# [677]	validation_0-rmse:0.117216
# [678]	validation_0-rmse:0.117133
# [679]	validation_0-rmse:0.11707
# [680]	validation_0-rmse:0.117059
# [681]	validation_0-rmse:0.117015
# [682]	validation_0-rmse:0.116928
# [683]	validation_0-rmse:0.116893
# [684]	validation_0-rmse:0.116869
# [685]	validation_0-rmse:0.116786
# [686]	validation_0-rmse:0.116731
# [687]	validation_0-rmse:0.116713
# [688]	validation_0-rmse:0.116665
# [689]	validation_0-rmse:0.116622
# [690]	validation_0-rmse:0.116619
# [691]	validation_0-rmse:0.116591
# [692]	validation_0-rmse:0.116536
# [693]	validation_0-rmse:0.116534
# [694]	validation_0-rmse:0.116504
# [695]	validation_0-rmse:0.116466
# [696]	validation_0-rmse:0.116459
# [697]	validation_0-rmse:0.116419
# [698]	validation_0-rmse:0.116342
# [699]	validation_0-rmse:0.116319
# [700]	validation_0-rmse:0.116239
# [701]	validation_0-rmse:0.116205
# [702]	validation_0-rmse:0.116153
# [703]	validation_0-rmse:0.116098
# [704]	validation_0-rmse:0.116077
# [705]	validation_0-rmse:0.116034
# [706]	validation_0-rmse:0.115989
# [707]	validation_0-rmse:0.115926
# [708]	validation_0-rmse:0.115937
# [709]	validation_0-rmse:0.115899
# [710]	validation_0-rmse:0.11585
# [711]	validation_0-rmse:0.115798
# [712]	validation_0-rmse:0.115717
# [713]	validation_0-rmse:0.115671
# [714]	validation_0-rmse:0.115687
# [715]	validation_0-rmse:0.115661
# [716]	validation_0-rmse:0.115617
# [717]	validation_0-rmse:0.115617
# [718]	validation_0-rmse:0.115614
# [719]	validation_0-rmse:0.115626
# [720]	validation_0-rmse:0.115562
# [721]	validation_0-rmse:0.115492
# [722]	validation_0-rmse:0.11543
# [723]	validation_0-rmse:0.115362
# [724]	validation_0-rmse:0.115334
# [725]	validation_0-rmse:0.11533
# [726]	validation_0-rmse:0.11527
# [727]	validation_0-rmse:0.115234
# [728]	validation_0-rmse:0.115213
# [729]	validation_0-rmse:0.115172
# [730]	validation_0-rmse:0.115166
# [731]	validation_0-rmse:0.115134
# [732]	validation_0-rmse:0.11507
# [733]	validation_0-rmse:0.115048
# [734]	validation_0-rmse:0.115048
# [735]	validation_0-rmse:0.115053
# [736]	validation_0-rmse:0.115057
# [737]	validation_0-rmse:0.115024
# [738]	validation_0-rmse:0.115014
# [739]	validation_0-rmse:0.11503
# [740]	validation_0-rmse:0.114972
# [741]	validation_0-rmse:0.114919
# [742]	validation_0-rmse:0.114879
# [743]	validation_0-rmse:0.114849
# [744]	validation_0-rmse:0.114834
# [745]	validation_0-rmse:0.114758
# [746]	validation_0-rmse:0.114752
# [747]	validation_0-rmse:0.114732
# [748]	validation_0-rmse:0.114716
# [749]	validation_0-rmse:0.114653
# [750]	validation_0-rmse:0.114625
# [751]	validation_0-rmse:0.114624
# [752]	validation_0-rmse:0.114649
# [753]	validation_0-rmse:0.114599
# [754]	validation_0-rmse:0.114566
# [755]	validation_0-rmse:0.114592
# [756]	validation_0-rmse:0.114556
# [757]	validation_0-rmse:0.114544
# [758]	validation_0-rmse:0.114518
# [759]	validation_0-rmse:0.1145
# [760]	validation_0-rmse:0.114444
# [761]	validation_0-rmse:0.11439
# [762]	validation_0-rmse:0.114353
# [763]	validation_0-rmse:0.114307
# [764]	validation_0-rmse:0.114297
# [765]	validation_0-rmse:0.114238
# [766]	validation_0-rmse:0.114222
# [767]	validation_0-rmse:0.114192
# [768]	validation_0-rmse:0.114138
# [769]	validation_0-rmse:0.11412
# [770]	validation_0-rmse:0.114072
# [771]	validation_0-rmse:0.114018
# [772]	validation_0-rmse:0.113991
# [773]	validation_0-rmse:0.113978
# [774]	validation_0-rmse:0.113958
# [775]	validation_0-rmse:0.113884
# [776]	validation_0-rmse:0.113849
# [777]	validation_0-rmse:0.113843
# [778]	validation_0-rmse:0.113807
# [779]	validation_0-rmse:0.113794
# [780]	validation_0-rmse:0.113777
# [781]	validation_0-rmse:0.113749
# [782]	validation_0-rmse:0.113716
# [783]	validation_0-rmse:0.11367
# [784]	validation_0-rmse:0.113618
# [785]	validation_0-rmse:0.113592
# [786]	validation_0-rmse:0.113558
# [787]	validation_0-rmse:0.113518
# [788]	validation_0-rmse:0.113465
# [789]	validation_0-rmse:0.11346
# [790]	validation_0-rmse:0.113483
# [791]	validation_0-rmse:0.11349
# [792]	validation_0-rmse:0.113491
# [793]	validation_0-rmse:0.113493
# [794]	validation_0-rmse:0.113445
# [795]	validation_0-rmse:0.113429
# [796]	validation_0-rmse:0.113413
# [797]	validation_0-rmse:0.113412
# [798]	validation_0-rmse:0.113393
# [799]	validation_0-rmse:0.113359
# [800]	validation_0-rmse:0.113311
# [801]	validation_0-rmse:0.113274
# [802]	validation_0-rmse:0.113309
# [803]	validation_0-rmse:0.113307
# [804]	validation_0-rmse:0.113286
# [805]	validation_0-rmse:0.113267
# [806]	validation_0-rmse:0.113276
# [807]	validation_0-rmse:0.113271
# [808]	validation_0-rmse:0.113219
# [809]	validation_0-rmse:0.113209
# [810]	validation_0-rmse:0.113244
# [811]	validation_0-rmse:0.113196
# [812]	validation_0-rmse:0.113169
# [813]	validation_0-rmse:0.113165
# [814]	validation_0-rmse:0.113113
# [815]	validation_0-rmse:0.113118
# [816]	validation_0-rmse:0.11309
# [817]	validation_0-rmse:0.11305
# [818]	validation_0-rmse:0.113023
# [819]	validation_0-rmse:0.113004
# [820]	validation_0-rmse:0.112997
# [821]	validation_0-rmse:0.112965
# [822]	validation_0-rmse:0.1129
# [823]	validation_0-rmse:0.112887
# [824]	validation_0-rmse:0.112888
# [825]	validation_0-rmse:0.11281
# [826]	validation_0-rmse:0.112774
# [827]	validation_0-rmse:0.112777
# [828]	validation_0-rmse:0.112795
# [829]	validation_0-rmse:0.112755
# [830]	validation_0-rmse:0.112759
# [831]	validation_0-rmse:0.112733
# [832]	validation_0-rmse:0.112689
# [833]	validation_0-rmse:0.112638
# [834]	validation_0-rmse:0.112608
# [835]	validation_0-rmse:0.112584
# [836]	validation_0-rmse:0.112551
# [837]	validation_0-rmse:0.112551
# [838]	validation_0-rmse:0.112511
# [839]	validation_0-rmse:0.112465
# [840]	validation_0-rmse:0.112446
# [841]	validation_0-rmse:0.112414
# [842]	validation_0-rmse:0.112396
# [843]	validation_0-rmse:0.112399
# [844]	validation_0-rmse:0.112386
# [845]	validation_0-rmse:0.112383
# [846]	validation_0-rmse:0.112379
# [847]	validation_0-rmse:0.11238
# [848]	validation_0-rmse:0.112361
# [849]	validation_0-rmse:0.112315
# [850]	validation_0-rmse:0.112292
# [851]	validation_0-rmse:0.112275
# [852]	validation_0-rmse:0.112262
# [853]	validation_0-rmse:0.112249
# [854]	validation_0-rmse:0.11225
# [855]	validation_0-rmse:0.112259
# [856]	validation_0-rmse:0.112238
# [857]	validation_0-rmse:0.112251
# [858]	validation_0-rmse:0.112259
# [859]	validation_0-rmse:0.11223
# [860]	validation_0-rmse:0.112228
# [861]	validation_0-rmse:0.112219
# [862]	validation_0-rmse:0.112191
# [863]	validation_0-rmse:0.112156
# [864]	validation_0-rmse:0.112137
# [865]	validation_0-rmse:0.112124
# [866]	validation_0-rmse:0.11212
# [867]	validation_0-rmse:0.112135
# [868]	validation_0-rmse:0.112084
# [869]	validation_0-rmse:0.112118
# [870]	validation_0-rmse:0.112106
# [871]	validation_0-rmse:0.112102
# [872]	validation_0-rmse:0.112108
# [873]	validation_0-rmse:0.112077
# [874]	validation_0-rmse:0.112055
# [875]	validation_0-rmse:0.112061
# [876]	validation_0-rmse:0.112033
# [877]	validation_0-rmse:0.112002
# [878]	validation_0-rmse:0.111982
# [879]	validation_0-rmse:0.111949
# [880]	validation_0-rmse:0.11196
# [881]	validation_0-rmse:0.111956
# [882]	validation_0-rmse:0.111915
# [883]	validation_0-rmse:0.111912
# [884]	validation_0-rmse:0.111903
# [885]	validation_0-rmse:0.111858
# [886]	validation_0-rmse:0.111861
# [887]	validation_0-rmse:0.111825
# [888]	validation_0-rmse:0.111817
# [889]	validation_0-rmse:0.111804
# [890]	validation_0-rmse:0.111819
# [891]	validation_0-rmse:0.111835
# [892]	validation_0-rmse:0.111807
# [893]	validation_0-rmse:0.111798
# [894]	validation_0-rmse:0.111812
# [895]	validation_0-rmse:0.111819
# [896]	validation_0-rmse:0.11183
# [897]	validation_0-rmse:0.111828
# [898]	validation_0-rmse:0.111849
# [899]	validation_0-rmse:0.111815
# [900]	validation_0-rmse:0.11183
# [901]	validation_0-rmse:0.111826
# [902]	validation_0-rmse:0.111797
# [903]	validation_0-rmse:0.111817
# [904]	validation_0-rmse:0.111805
# [905]	validation_0-rmse:0.111785
# [906]	validation_0-rmse:0.111763
# [907]	validation_0-rmse:0.111766
# [908]	validation_0-rmse:0.11179
# [909]	validation_0-rmse:0.111765
# [910]	validation_0-rmse:0.111729
# [911]	validation_0-rmse:0.111736
# [912]	validation_0-rmse:0.111694
# [913]	validation_0-rmse:0.11168
# [914]	validation_0-rmse:0.11167
# [915]	validation_0-rmse:0.111669
# [916]	validation_0-rmse:0.111631
# [917]	validation_0-rmse:0.111615
# [918]	validation_0-rmse:0.1116
# [919]	validation_0-rmse:0.111547
# [920]	validation_0-rmse:0.11154
# [921]	validation_0-rmse:0.111498
# [922]	validation_0-rmse:0.111506
# [923]	validation_0-rmse:0.111525
# [924]	validation_0-rmse:0.111522
# [925]	validation_0-rmse:0.111525
# [926]	validation_0-rmse:0.11149
# [927]	validation_0-rmse:0.111454
# [928]	validation_0-rmse:0.111431
# [929]	validation_0-rmse:0.111414
# [930]	validation_0-rmse:0.111378
# [931]	validation_0-rmse:0.111368
# [932]	validation_0-rmse:0.111373
# [933]	validation_0-rmse:0.111389
# [934]	validation_0-rmse:0.111375
# [935]	validation_0-rmse:0.111357
# [936]	validation_0-rmse:0.111312
# [937]	validation_0-rmse:0.111313
# [938]	validation_0-rmse:0.111257
# [939]	validation_0-rmse:0.111247
# [940]	validation_0-rmse:0.111242
# [941]	validation_0-rmse:0.111242
# [942]	validation_0-rmse:0.111213
# [943]	validation_0-rmse:0.111197
# [944]	validation_0-rmse:0.111166
# [945]	validation_0-rmse:0.111139
# [946]	validation_0-rmse:0.111127
# [947]	validation_0-rmse:0.111112
# [948]	validation_0-rmse:0.111111
# [949]	validation_0-rmse:0.111154
# [950]	validation_0-rmse:0.111164
# [951]	validation_0-rmse:0.111133
# [952]	validation_0-rmse:0.111133
# [953]	validation_0-rmse:0.111094
# [954]	validation_0-rmse:0.111068
# [955]	validation_0-rmse:0.111067
# [956]	validation_0-rmse:0.111023
# [957]	validation_0-rmse:0.11102
# [958]	validation_0-rmse:0.111015
# [959]	validation_0-rmse:0.110997
# [960]	validation_0-rmse:0.111023
# [961]	validation_0-rmse:0.111027
# [962]	validation_0-rmse:0.111047
# [963]	validation_0-rmse:0.111051
# [964]	validation_0-rmse:0.111081
# [965]	validation_0-rmse:0.111061
# [966]	validation_0-rmse:0.111076
# [967]	validation_0-rmse:0.111062
# [968]	validation_0-rmse:0.111047
# [969]	validation_0-rmse:0.111017
# [970]	validation_0-rmse:0.111023
# [971]	validation_0-rmse:0.110999
# [972]	validation_0-rmse:0.111014
# [973]	validation_0-rmse:0.110961
# [974]	validation_0-rmse:0.110952
# [975]	validation_0-rmse:0.110952
# [976]	validation_0-rmse:0.110948
# [977]	validation_0-rmse:0.11093
# [978]	validation_0-rmse:0.110958
# [979]	validation_0-rmse:0.11096
# [980]	validation_0-rmse:0.110968
# [981]	validation_0-rmse:0.110953
# [982]	validation_0-rmse:0.110948
# [983]	validation_0-rmse:0.110924
# [984]	validation_0-rmse:0.110927
# [985]	validation_0-rmse:0.110889
# [986]	validation_0-rmse:0.110897
# [987]	validation_0-rmse:0.110906
# [988]	validation_0-rmse:0.110886
# [989]	validation_0-rmse:0.110841
# [990]	validation_0-rmse:0.110812
# [991]	validation_0-rmse:0.110799
# [992]	validation_0-rmse:0.110785
# [993]	validation_0-rmse:0.110772
# [994]	validation_0-rmse:0.110769
# [995]	validation_0-rmse:0.110756
# [996]	validation_0-rmse:0.110742
# [997]	validation_0-rmse:0.110736
# [998]	validation_0-rmse:0.110746
# [999]	validation_0-rmse:0.110734
# [1000]	validation_0-rmse:0.110705
# [1001]	validation_0-rmse:0.110713
# [1002]	validation_0-rmse:0.11069
# [1003]	validation_0-rmse:0.110688
# [1004]	validation_0-rmse:0.110689
# [1005]	validation_0-rmse:0.110673
# [1006]	validation_0-rmse:0.110645
# [1007]	validation_0-rmse:0.110638
# [1008]	validation_0-rmse:0.110613
# [1009]	validation_0-rmse:0.110589
# [1010]	validation_0-rmse:0.1106
# [1011]	validation_0-rmse:0.110602
# [1012]	validation_0-rmse:0.110615
# [1013]	validation_0-rmse:0.110624
# [1014]	validation_0-rmse:0.110606
# [1015]	validation_0-rmse:0.110598
# [1016]	validation_0-rmse:0.110585
# [1017]	validation_0-rmse:0.110581
# [1018]	validation_0-rmse:0.110571
# [1019]	validation_0-rmse:0.110614
# [1020]	validation_0-rmse:0.110606
# [1021]	validation_0-rmse:0.110559
# [1022]	validation_0-rmse:0.110549
# [1023]	validation_0-rmse:0.110533
# [1024]	validation_0-rmse:0.110491
# [1025]	validation_0-rmse:0.11046
# [1026]	validation_0-rmse:0.110446
# [1027]	validation_0-rmse:0.110454
# [1028]	validation_0-rmse:0.11046
# [1029]	validation_0-rmse:0.110446
# [1030]	validation_0-rmse:0.110459
# [1031]	validation_0-rmse:0.110457
# [1032]	validation_0-rmse:0.110462
# [1033]	validation_0-rmse:0.110455
# [1034]	validation_0-rmse:0.110436
# [1035]	validation_0-rmse:0.110406
# [1036]	validation_0-rmse:0.110388
# [1037]	validation_0-rmse:0.110354
# [1038]	validation_0-rmse:0.11036
# [1039]	validation_0-rmse:0.110316
# [1040]	validation_0-rmse:0.110296
# [1041]	validation_0-rmse:0.110293
# [1042]	validation_0-rmse:0.110277
# [1043]	validation_0-rmse:0.11026
# [1044]	validation_0-rmse:0.11025
# [1045]	validation_0-rmse:0.110251
# [1046]	validation_0-rmse:0.110225
# [1047]	validation_0-rmse:0.110183
# [1048]	validation_0-rmse:0.110191
# [1049]	validation_0-rmse:0.11018
# [1050]	validation_0-rmse:0.110185
# [1051]	validation_0-rmse:0.110162
# [1052]	validation_0-rmse:0.110147
# [1053]	validation_0-rmse:0.110138
# [1054]	validation_0-rmse:0.110129
# [1055]	validation_0-rmse:0.110105
# [1056]	validation_0-rmse:0.110093
# [1057]	validation_0-rmse:0.110104
# [1058]	validation_0-rmse:0.110104
# [1059]	validation_0-rmse:0.110093
# [1060]	validation_0-rmse:0.110072
# [1061]	validation_0-rmse:0.110066
# [1062]	validation_0-rmse:0.110081
# [1063]	validation_0-rmse:0.110085
# [1064]	validation_0-rmse:0.110062
# [1065]	validation_0-rmse:0.110021
# [1066]	validation_0-rmse:0.110031
# [1067]	validation_0-rmse:0.110033
# [1068]	validation_0-rmse:0.110042
# [1069]	validation_0-rmse:0.11004
# [1070]	validation_0-rmse:0.110058
# [1071]	validation_0-rmse:0.11009
# [1072]	validation_0-rmse:0.11008
# [1073]	validation_0-rmse:0.110062
# [1074]	validation_0-rmse:0.110083
# [1075]	validation_0-rmse:0.110048
# [1076]	validation_0-rmse:0.110045
# [1077]	validation_0-rmse:0.110051
# [1078]	validation_0-rmse:0.110035
# [1079]	validation_0-rmse:0.110045
# [1080]	validation_0-rmse:0.110024
# [1081]	validation_0-rmse:0.110028
# [1082]	validation_0-rmse:0.110034
# [1083]	validation_0-rmse:0.110018
# [1084]	validation_0-rmse:0.109999
# [1085]	validation_0-rmse:0.109989
# [1086]	validation_0-rmse:0.109994
# [1087]	validation_0-rmse:0.109984
# [1088]	validation_0-rmse:0.110007
# [1089]	validation_0-rmse:0.110001
# [1090]	validation_0-rmse:0.109994
# [1091]	validation_0-rmse:0.109983
# [1092]	validation_0-rmse:0.109959
# [1093]	validation_0-rmse:0.109968
# [1094]	validation_0-rmse:0.10995
# [1095]	validation_0-rmse:0.109929
# [1096]	validation_0-rmse:0.109888
# [1097]	validation_0-rmse:0.109869
# [1098]	validation_0-rmse:0.10984
# [1099]	validation_0-rmse:0.109885
# [1100]	validation_0-rmse:0.10987
# [1101]	validation_0-rmse:0.109855
# [1102]	validation_0-rmse:0.109831
# [1103]	validation_0-rmse:0.109808
# [1104]	validation_0-rmse:0.109789
# [1105]	validation_0-rmse:0.109792
# [1106]	validation_0-rmse:0.109771
# [1107]	validation_0-rmse:0.109768
# [1108]	validation_0-rmse:0.109759
# [1109]	validation_0-rmse:0.10975
# [1110]	validation_0-rmse:0.109712
# [1111]	validation_0-rmse:0.109744
# [1112]	validation_0-rmse:0.109701
# [1113]	validation_0-rmse:0.109719
# [1114]	validation_0-rmse:0.109719
# [1115]	validation_0-rmse:0.109702
# [1116]	validation_0-rmse:0.109717
# [1117]	validation_0-rmse:0.109696
# [1118]	validation_0-rmse:0.109695
# [1119]	validation_0-rmse:0.109693
# [1120]	validation_0-rmse:0.109687
# [1121]	validation_0-rmse:0.109687
# [1122]	validation_0-rmse:0.109686
# [1123]	validation_0-rmse:0.109686
# [1124]	validation_0-rmse:0.109656
# [1125]	validation_0-rmse:0.109642
# [1126]	validation_0-rmse:0.109632
# [1127]	validation_0-rmse:0.109626
# [1128]	validation_0-rmse:0.109616
# [1129]	validation_0-rmse:0.109585
# [1130]	validation_0-rmse:0.109584
# [1131]	validation_0-rmse:0.10961
# [1132]	validation_0-rmse:0.109609
# [1133]	validation_0-rmse:0.109588
# [1134]	validation_0-rmse:0.109582
# [1135]	validation_0-rmse:0.109583
# [1136]	validation_0-rmse:0.109561
# [1137]	validation_0-rmse:0.109555
# [1138]	validation_0-rmse:0.10953
# [1139]	validation_0-rmse:0.109519
# [1140]	validation_0-rmse:0.109515
# [1141]	validation_0-rmse:0.109519
# [1142]	validation_0-rmse:0.109491
# [1143]	validation_0-rmse:0.109519
# [1144]	validation_0-rmse:0.109507
# [1145]	validation_0-rmse:0.109525
# [1146]	validation_0-rmse:0.109512
# [1147]	validation_0-rmse:0.109487
# [1148]	validation_0-rmse:0.1095
# [1149]	validation_0-rmse:0.109494
# [1150]	validation_0-rmse:0.109489
# [1151]	validation_0-rmse:0.109491
# [1152]	validation_0-rmse:0.109476
# [1153]	validation_0-rmse:0.109473
# [1154]	validation_0-rmse:0.109471
# [1155]	validation_0-rmse:0.109484
# [1156]	validation_0-rmse:0.109494
# [1157]	validation_0-rmse:0.109488
# [1158]	validation_0-rmse:0.109486
# [1159]	validation_0-rmse:0.109483
# [1160]	validation_0-rmse:0.109486
# [1161]	validation_0-rmse:0.109469
# [1162]	validation_0-rmse:0.109468
# [1163]	validation_0-rmse:0.109479
# [1164]	validation_0-rmse:0.109483
# [1165]	validation_0-rmse:0.109467
# [1166]	validation_0-rmse:0.109467
# [1167]	validation_0-rmse:0.109446
# [1168]	validation_0-rmse:0.109452
# [1169]	validation_0-rmse:0.109479
# [1170]	validation_0-rmse:0.109449
# [1171]	validation_0-rmse:0.109435
# [1172]	validation_0-rmse:0.109411
# [1173]	validation_0-rmse:0.109425
# [1174]	validation_0-rmse:0.109417
# [1175]	validation_0-rmse:0.109424
# [1176]	validation_0-rmse:0.109399
# [1177]	validation_0-rmse:0.109386
# [1178]	validation_0-rmse:0.109376
# [1179]	validation_0-rmse:0.109366
# [1180]	validation_0-rmse:0.109367
# [1181]	validation_0-rmse:0.109358
# [1182]	validation_0-rmse:0.109359
# [1183]	validation_0-rmse:0.109369
# [1184]	validation_0-rmse:0.109353
# [1185]	validation_0-rmse:0.109334
# [1186]	validation_0-rmse:0.109365
# [1187]	validation_0-rmse:0.109338
# [1188]	validation_0-rmse:0.109328
# [1189]	validation_0-rmse:0.109319
# [1190]	validation_0-rmse:0.109294
# [1191]	validation_0-rmse:0.109314
# [1192]	validation_0-rmse:0.109319
# [1193]	validation_0-rmse:0.109292
# [1194]	validation_0-rmse:0.109287
# [1195]	validation_0-rmse:0.109272
# [1196]	validation_0-rmse:0.109249
# [1197]	validation_0-rmse:0.109229
# [1198]	validation_0-rmse:0.109204
# [1199]	validation_0-rmse:0.109202
# [1200]	validation_0-rmse:0.109205
# [1201]	validation_0-rmse:0.109211
# [1202]	validation_0-rmse:0.109217
# [1203]	validation_0-rmse:0.109206
# [1204]	validation_0-rmse:0.109183
# [1205]	validation_0-rmse:0.109173
# [1206]	validation_0-rmse:0.109164
# [1207]	validation_0-rmse:0.109159
# [1208]	validation_0-rmse:0.109151
# [1209]	validation_0-rmse:0.10917
# [1210]	validation_0-rmse:0.10918
# [1211]	validation_0-rmse:0.109152
# [1212]	validation_0-rmse:0.109162
# [1213]	validation_0-rmse:0.109169
# [1214]	validation_0-rmse:0.109172
# [1215]	validation_0-rmse:0.109163
# [1216]	validation_0-rmse:0.109149
# [1217]	validation_0-rmse:0.109117
# [1218]	validation_0-rmse:0.109103
# [1219]	validation_0-rmse:0.109074
# [1220]	validation_0-rmse:0.109086
# [1221]	validation_0-rmse:0.109073
# [1222]	validation_0-rmse:0.109061
# [1223]	validation_0-rmse:0.109049
# [1224]	validation_0-rmse:0.109072
# [1225]	validation_0-rmse:0.109061
# [1226]	validation_0-rmse:0.109049
# [1227]	validation_0-rmse:0.109049
# [1228]	validation_0-rmse:0.109025
# [1229]	validation_0-rmse:0.109028
# [1230]	validation_0-rmse:0.109016
# [1231]	validation_0-rmse:0.108989
# [1232]	validation_0-rmse:0.10897
# [1233]	validation_0-rmse:0.10898
# [1234]	validation_0-rmse:0.108982
# [1235]	validation_0-rmse:0.109001
# [1236]	validation_0-rmse:0.108986
# [1237]	validation_0-rmse:0.108991
# [1238]	validation_0-rmse:0.108981
# [1239]	validation_0-rmse:0.108963
# [1240]	validation_0-rmse:0.108971
# [1241]	validation_0-rmse:0.108964
# [1242]	validation_0-rmse:0.108956
# [1243]	validation_0-rmse:0.108957
# [1244]	validation_0-rmse:0.10896
# [1245]	validation_0-rmse:0.108966
# [1246]	validation_0-rmse:0.108983
# [1247]	validation_0-rmse:0.108976
# [1248]	validation_0-rmse:0.10898
# [1249]	validation_0-rmse:0.108982
# [1250]	validation_0-rmse:0.108996
# [1251]	validation_0-rmse:0.108996
# [1252]	validation_0-rmse:0.108981
# [1253]	validation_0-rmse:0.108986
# [1254]	validation_0-rmse:0.108982
# [1255]	validation_0-rmse:0.108984
# [1256]	validation_0-rmse:0.108984
# [1257]	validation_0-rmse:0.108978
# [1258]	validation_0-rmse:0.108987
# [1259]	validation_0-rmse:0.108975
# [1260]	validation_0-rmse:0.108981
# [1261]	validation_0-rmse:0.108966
# [1262]	validation_0-rmse:0.10896
# [1263]	validation_0-rmse:0.10896
# [1264]	validation_0-rmse:0.108936
# [1265]	validation_0-rmse:0.108955
# [1266]	validation_0-rmse:0.10894
# [1267]	validation_0-rmse:0.108936
# [1268]	validation_0-rmse:0.10892
# [1269]	validation_0-rmse:0.108924
# [1270]	validation_0-rmse:0.108925
# [1271]	validation_0-rmse:0.108904
# [1272]	validation_0-rmse:0.108899
# [1273]	validation_0-rmse:0.108926
# [1274]	validation_0-rmse:0.108915
# [1275]	validation_0-rmse:0.108902
# [1276]	validation_0-rmse:0.108899
# [1277]	validation_0-rmse:0.108884
# [1278]	validation_0-rmse:0.108868
# [1279]	validation_0-rmse:0.108867
# [1280]	validation_0-rmse:0.108841
# [1281]	validation_0-rmse:0.108839
# [1282]	validation_0-rmse:0.108842
# [1283]	validation_0-rmse:0.10884
# [1284]	validation_0-rmse:0.108809
# [1285]	validation_0-rmse:0.108816
# [1286]	validation_0-rmse:0.10881
# [1287]	validation_0-rmse:0.108808
# [1288]	validation_0-rmse:0.108807
# [1289]	validation_0-rmse:0.108795
# [1290]	validation_0-rmse:0.108782
# [1291]	validation_0-rmse:0.108796
# [1292]	validation_0-rmse:0.108791
# [1293]	validation_0-rmse:0.108778
# [1294]	validation_0-rmse:0.108757
# [1295]	validation_0-rmse:0.108761
# [1296]	validation_0-rmse:0.108742
# [1297]	validation_0-rmse:0.108747
# [1298]	validation_0-rmse:0.108755
# [1299]	validation_0-rmse:0.10875
# [1300]	validation_0-rmse:0.108744
# [1301]	validation_0-rmse:0.108737
# [1302]	validation_0-rmse:0.108722
# [1303]	validation_0-rmse:0.108704
# [1304]	validation_0-rmse:0.108706
# [1305]	validation_0-rmse:0.108711
# [1306]	validation_0-rmse:0.108704
# [1307]	validation_0-rmse:0.108679
# [1308]	validation_0-rmse:0.108649
# [1309]	validation_0-rmse:0.108656
# [1310]	validation_0-rmse:0.108643
# [1311]	validation_0-rmse:0.108635
# [1312]	validation_0-rmse:0.108626
# [1313]	validation_0-rmse:0.108621
# [1314]	validation_0-rmse:0.108591
# [1315]	validation_0-rmse:0.108555
# [1316]	validation_0-rmse:0.10854
# [1317]	validation_0-rmse:0.108538
# [1318]	validation_0-rmse:0.108545
# [1319]	validation_0-rmse:0.108552
# [1320]	validation_0-rmse:0.108546
# [1321]	validation_0-rmse:0.108549
# [1322]	validation_0-rmse:0.108568
# [1323]	validation_0-rmse:0.10856
# [1324]	validation_0-rmse:0.10855
# [1325]	validation_0-rmse:0.108542
# [1326]	validation_0-rmse:0.108559
# [1327]	validation_0-rmse:0.108543
# [1328]	validation_0-rmse:0.108528
# [1329]	validation_0-rmse:0.108544
# [1330]	validation_0-rmse:0.108519
# [1331]	validation_0-rmse:0.108516
# [1332]	validation_0-rmse:0.108527
# [1333]	validation_0-rmse:0.108504
# [1334]	validation_0-rmse:0.108519
# [1335]	validation_0-rmse:0.108528
# [1336]	validation_0-rmse:0.108513
# [1337]	validation_0-rmse:0.108511
# [1338]	validation_0-rmse:0.10849
# [1339]	validation_0-rmse:0.10849
# [1340]	validation_0-rmse:0.108496
# [1341]	validation_0-rmse:0.108509
# [1342]	validation_0-rmse:0.108515
# [1343]	validation_0-rmse:0.108496
# [1344]	validation_0-rmse:0.108477
# [1345]	validation_0-rmse:0.108477
# [1346]	validation_0-rmse:0.108476
# [1347]	validation_0-rmse:0.108453
# [1348]	validation_0-rmse:0.108443
# [1349]	validation_0-rmse:0.108442
# [1350]	validation_0-rmse:0.108451
# [1351]	validation_0-rmse:0.108453
# [1352]	validation_0-rmse:0.108445
# [1353]	validation_0-rmse:0.108437
# [1354]	validation_0-rmse:0.108432
# [1355]	validation_0-rmse:0.108423
# [1356]	validation_0-rmse:0.108419
# [1357]	validation_0-rmse:0.108429
# [1358]	validation_0-rmse:0.10844
# [1359]	validation_0-rmse:0.108456
# [1360]	validation_0-rmse:0.108457
# [1361]	validation_0-rmse:0.108467
# [1362]	validation_0-rmse:0.108448
# [1363]	validation_0-rmse:0.108447
# [1364]	validation_0-rmse:0.108409
# [1365]	validation_0-rmse:0.108428
# [1366]	validation_0-rmse:0.108445
# [1367]	validation_0-rmse:0.108456
# [1368]	validation_0-rmse:0.108456
# [1369]	validation_0-rmse:0.108445
# [1370]	validation_0-rmse:0.108432
# [1371]	validation_0-rmse:0.108395
# [1372]	validation_0-rmse:0.108394
# [1373]	validation_0-rmse:0.108396
# [1374]	validation_0-rmse:0.108386
# [1375]	validation_0-rmse:0.108398
# [1376]	validation_0-rmse:0.108382
# [1377]	validation_0-rmse:0.10839
# [1378]	validation_0-rmse:0.108399
# [1379]	validation_0-rmse:0.108389
# [1380]	validation_0-rmse:0.108391
# [1381]	validation_0-rmse:0.108383
# [1382]	validation_0-rmse:0.108407
# [1383]	validation_0-rmse:0.108387
# [1384]	validation_0-rmse:0.108409
# [1385]	validation_0-rmse:0.108413
# [1386]	validation_0-rmse:0.108386
# [1387]	validation_0-rmse:0.108367
# [1388]	validation_0-rmse:0.108356
# [1389]	validation_0-rmse:0.10835
# [1390]	validation_0-rmse:0.108357
# [1391]	validation_0-rmse:0.108365
# [1392]	validation_0-rmse:0.108352
# [1393]	validation_0-rmse:0.108353
# [1394]	validation_0-rmse:0.108345
# [1395]	validation_0-rmse:0.108341
# [1396]	validation_0-rmse:0.108314
# [1397]	validation_0-rmse:0.108321
# [1398]	validation_0-rmse:0.10831
# [1399]	validation_0-rmse:0.108283
# [1400]	validation_0-rmse:0.108261
# [1401]	validation_0-rmse:0.108266
# [1402]	validation_0-rmse:0.108261
# [1403]	validation_0-rmse:0.108254
# [1404]	validation_0-rmse:0.10826
# [1405]	validation_0-rmse:0.108253
# [1406]	validation_0-rmse:0.108251
# [1407]	validation_0-rmse:0.108241
# [1408]	validation_0-rmse:0.108233
# [1409]	validation_0-rmse:0.108246
# [1410]	validation_0-rmse:0.108251
# [1411]	validation_0-rmse:0.108239
# [1412]	validation_0-rmse:0.10822
# [1413]	validation_0-rmse:0.108223
# [1414]	validation_0-rmse:0.108233
# [1415]	validation_0-rmse:0.108226
# [1416]	validation_0-rmse:0.108221
# [1417]	validation_0-rmse:0.108208
# [1418]	validation_0-rmse:0.108191
# [1419]	validation_0-rmse:0.108183
# [1420]	validation_0-rmse:0.10818
# [1421]	validation_0-rmse:0.108178
# [1422]	validation_0-rmse:0.108185
# [1423]	validation_0-rmse:0.108202
# [1424]	validation_0-rmse:0.108178
# [1425]	validation_0-rmse:0.108206
# [1426]	validation_0-rmse:0.108197
# [1427]	validation_0-rmse:0.108164
# [1428]	validation_0-rmse:0.108179
# [1429]	validation_0-rmse:0.108178
# [1430]	validation_0-rmse:0.108152
# [1431]	validation_0-rmse:0.108151
# [1432]	validation_0-rmse:0.108121
# [1433]	validation_0-rmse:0.108122
# [1434]	validation_0-rmse:0.108121
# [1435]	validation_0-rmse:0.108116
# [1436]	validation_0-rmse:0.10813
# [1437]	validation_0-rmse:0.108105
# [1438]	validation_0-rmse:0.108099
# [1439]	validation_0-rmse:0.108083
# [1440]	validation_0-rmse:0.108093
# [1441]	validation_0-rmse:0.108104
# [1442]	validation_0-rmse:0.108106
# [1443]	validation_0-rmse:0.108095
# [1444]	validation_0-rmse:0.108091
# [1445]	validation_0-rmse:0.108101
# [1446]	validation_0-rmse:0.108108
# [1447]	validation_0-rmse:0.1081
# [1448]	validation_0-rmse:0.108076
# [1449]	validation_0-rmse:0.108051
# [1450]	validation_0-rmse:0.108045
# [1451]	validation_0-rmse:0.108051
# [1452]	validation_0-rmse:0.108047
# [1453]	validation_0-rmse:0.108036
# ...
# [2205]	validation_0-rmse:0.105755
# [2206]	validation_0-rmse:0.10575
# [2207]	validation_0-rmse:0.105752
# [2208]	validation_0-rmse:0.105749
# [2209]	validation_0-rmse:0.105751
# [2210]	validation_0-rmse:0.105744
# [2211]	validation_0-rmse:0.105744
# [2212]	validation_0-rmse:0.105742
# [2213]	validation_0-rmse:0.105753
# [2214]	validation_0-rmse:0.105754
# [2215]	validation_0-rmse:0.10575
# [2216]	validation_0-rmse:0.105743
# [2217]	validation_0-rmse:0.105723
# [2218]	validation_0-rmse:0.105721
# [2219]	validation_0-rmse:0.105713
# [2220]	validation_0-rmse:0.105715
# [2221]	validation_0-rmse:0.105709
# [2222]	validation_0-rmse:0.105713
# [2223]	validation_0-rmse:0.105709
# [2224]	validation_0-rmse:0.105728
# [2225]	validation_0-rmse:0.105705
# [2226]	validation_0-rmse:0.105712
# [2227]	validation_0-rmse:0.105706
# [2228]	validation_0-rmse:0.105707
# [2229]	validation_0-rmse:0.105699
# [2230]	validation_0-rmse:0.105702
# [2231]	validation_0-rmse:0.105695
# [2232]	validation_0-rmse:0.105683
# [2233]	validation_0-rmse:0.105692
# [2234]	validation_0-rmse:0.105693
# [2235]	validation_0-rmse:0.105708
# [2236]	validation_0-rmse:0.105707
# [2237]	validation_0-rmse:0.105713
# [2238]	validation_0-rmse:0.105725
# [2239]	validation_0-rmse:0.105721
# [2240]	validation_0-rmse:0.105721
# [2241]	validation_0-rmse:0.105717
# [2242]	validation_0-rmse:0.105709
# [2243]	validation_0-rmse:0.105702
# [2244]	validation_0-rmse:0.105691
# [2245]	validation_0-rmse:0.105686
# [2246]	validation_0-rmse:0.105692
# [2247]	validation_0-rmse:0.105696
# [2248]	validation_0-rmse:0.105697
# [2249]	validation_0-rmse:0.105702
# [2250]	validation_0-rmse:0.105695
# [2251]	validation_0-rmse:0.105692
# [2252]	validation_0-rmse:0.105681
# [2253]	validation_0-rmse:0.105669
# [2254]	validation_0-rmse:0.105664
# [2255]	validation_0-rmse:0.105664
# [2256]	validation_0-rmse:0.105662
# [2257]	validation_0-rmse:0.105658
# [2258]	validation_0-rmse:0.105674
# [2259]	validation_0-rmse:0.105676
# [2260]	validation_0-rmse:0.105675
# [2261]	validation_0-rmse:0.105655
# [2262]	validation_0-rmse:0.105664
# [2263]	validation_0-rmse:0.105677
# [2264]	validation_0-rmse:0.105682
# [2265]	validation_0-rmse:0.105692
# [2266]	validation_0-rmse:0.105684
# [2267]	validation_0-rmse:0.105685
# [2268]	validation_0-rmse:0.105671
# [2269]	validation_0-rmse:0.105658
# [2270]	validation_0-rmse:0.10565
# [2271]	validation_0-rmse:0.105643
# [2272]	validation_0-rmse:0.105646
# [2273]	validation_0-rmse:0.105643
# [2274]	validation_0-rmse:0.105637
# [2275]	validation_0-rmse:0.105652
# [2276]	validation_0-rmse:0.105661
# [2277]	validation_0-rmse:0.105668
# [2278]	validation_0-rmse:0.105656
# [2279]	validation_0-rmse:0.105638
# [2280]	validation_0-rmse:0.105654
# [2281]	validation_0-rmse:0.105652
# [2282]	validation_0-rmse:0.105652
# [2283]	validation_0-rmse:0.105673
# [2284]	validation_0-rmse:0.105669
# [2285]	validation_0-rmse:0.105672
# [2286]	validation_0-rmse:0.105667
# [2287]	validation_0-rmse:0.10568
# [2288]	validation_0-rmse:0.105677
# [2289]	validation_0-rmse:0.105685
# [2290]	validation_0-rmse:0.105683
# [2291]	validation_0-rmse:0.105681
# [2292]	validation_0-rmse:0.105676
# [2293]	validation_0-rmse:0.105687
# [2294]	validation_0-rmse:0.105692
# [2295]	validation_0-rmse:0.105682
# [2296]	validation_0-rmse:0.105703
# [2297]	validation_0-rmse:0.105711
# [2298]	validation_0-rmse:0.105711
# [2299]	validation_0-rmse:0.10572
# [2300]	validation_0-rmse:0.105712
# [2301]	validation_0-rmse:0.105705
# [2302]	validation_0-rmse:0.105677
# [2303]	validation_0-rmse:0.105675
# [2304]	validation_0-rmse:0.105673
# [2305]	validation_0-rmse:0.105672
# [2306]	validation_0-rmse:0.105652
# [2307]	validation_0-rmse:0.105656
# [2308]	validation_0-rmse:0.105666
# [2309]	validation_0-rmse:0.105663
# [2310]	validation_0-rmse:0.105665
# [2311]	validation_0-rmse:0.105657
# [2312]	validation_0-rmse:0.105653
# [2313]	validation_0-rmse:0.105657
# [2314]	validation_0-rmse:0.105656
# [2315]	validation_0-rmse:0.105669
# [2316]	validation_0-rmse:0.105667
# [2317]	validation_0-rmse:0.105641
# [2318]	validation_0-rmse:0.105656
# [2319]	validation_0-rmse:0.105658
# [2320]	validation_0-rmse:0.105653
# [2321]	validation_0-rmse:0.105643
# [2322]	validation_0-rmse:0.105652
# [2323]	validation_0-rmse:0.105653
# [2324]	validation_0-rmse:0.105635
# [2325]	validation_0-rmse:0.105636
# [2326]	validation_0-rmse:0.10563
# [2327]	validation_0-rmse:0.10562
# [2328]	validation_0-rmse:0.105622
# [2329]	validation_0-rmse:0.105627
# [2330]	validation_0-rmse:0.105634
# [2331]	validation_0-rmse:0.105638
# [2332]	validation_0-rmse:0.105627
# [2333]	validation_0-rmse:0.105639
# [2334]	validation_0-rmse:0.105634
# [2335]	validation_0-rmse:0.105631
# [2336]	validation_0-rmse:0.105623
# [2337]	validation_0-rmse:0.105611
# [2338]	validation_0-rmse:0.105626
# [2339]	validation_0-rmse:0.105609
# [2340]	validation_0-rmse:0.105614
# [2341]	validation_0-rmse:0.105614
# [2342]	validation_0-rmse:0.105614
# [2343]	validation_0-rmse:0.105611
# [2344]	validation_0-rmse:0.105603
# [2345]	validation_0-rmse:0.105599
# [2346]	validation_0-rmse:0.10559
# [2347]	validation_0-rmse:0.10559
# [2348]	validation_0-rmse:0.105588
# [2349]	validation_0-rmse:0.105587
# [2350]	validation_0-rmse:0.105577
# [2351]	validation_0-rmse:0.105569
# [2352]	validation_0-rmse:0.105571
# [2353]	validation_0-rmse:0.105579
# [2354]	validation_0-rmse:0.105584
# [2355]	validation_0-rmse:0.105588
# [2356]	validation_0-rmse:0.105578
# [2357]	validation_0-rmse:0.105574
# [2358]	validation_0-rmse:0.105572
# [2359]	validation_0-rmse:0.105577
# [2360]	validation_0-rmse:0.10559
# [2361]	validation_0-rmse:0.105588
# [2362]	validation_0-rmse:0.105565
# [2363]	validation_0-rmse:0.105571
# [2364]	validation_0-rmse:0.105575
# [2365]	validation_0-rmse:0.105572
# [2366]	validation_0-rmse:0.105565
# [2367]	validation_0-rmse:0.105581
# [2368]	validation_0-rmse:0.105556
# [2369]	validation_0-rmse:0.105539
# [2370]	validation_0-rmse:0.105527
# [2371]	validation_0-rmse:0.105533
# [2372]	validation_0-rmse:0.105538
# [2373]	validation_0-rmse:0.105541
# [2374]	validation_0-rmse:0.105534
# [2375]	validation_0-rmse:0.105545
# [2376]	validation_0-rmse:0.105539
# [2377]	validation_0-rmse:0.10553
# [2378]	validation_0-rmse:0.105531
# [2379]	validation_0-rmse:0.105544
# [2380]	validation_0-rmse:0.105556
# [2381]	validation_0-rmse:0.105544
# [2382]	validation_0-rmse:0.105543
# [2383]	validation_0-rmse:0.105527
# [2384]	validation_0-rmse:0.105521
# [2385]	validation_0-rmse:0.105521
# [2386]	validation_0-rmse:0.105503
# [2387]	validation_0-rmse:0.105509
# [2388]	validation_0-rmse:0.105508
# [2389]	validation_0-rmse:0.105508
# [2390]	validation_0-rmse:0.105489
# [2391]	validation_0-rmse:0.105495
# [2392]	validation_0-rmse:0.105497
# [2393]	validation_0-rmse:0.105494
# [2394]	validation_0-rmse:0.105487
# [2395]	validation_0-rmse:0.105489
# [2396]	validation_0-rmse:0.105494
# [2397]	validation_0-rmse:0.105501
# [2398]	validation_0-rmse:0.105498
# [2399]	validation_0-rmse:0.1055
# [2400]	validation_0-rmse:0.105493
# [2401]	validation_0-rmse:0.105495
# [2402]	validation_0-rmse:0.105503
# [2403]	validation_0-rmse:0.105499
# [2404]	validation_0-rmse:0.105505
# [2405]	validation_0-rmse:0.105494
# [2406]	validation_0-rmse:0.105502
# [2407]	validation_0-rmse:0.105494
# [2408]	validation_0-rmse:0.105496
# [2409]	validation_0-rmse:0.105506
# [2410]	validation_0-rmse:0.105492
# [2411]	validation_0-rmse:0.105493
# [2412]	validation_0-rmse:0.105481
# [2413]	validation_0-rmse:0.105486
# [2414]	validation_0-rmse:0.105482
# [2415]	validation_0-rmse:0.105497
# [2416]	validation_0-rmse:0.105496
# [2417]	validation_0-rmse:0.105497
# [2418]	validation_0-rmse:0.105502
# [2419]	validation_0-rmse:0.105509
# [2420]	validation_0-rmse:0.105513
# [2421]	validation_0-rmse:0.105525
# [2422]	validation_0-rmse:0.105511
# [2423]	validation_0-rmse:0.105508
# [2424]	validation_0-rmse:0.105507
# [2425]	validation_0-rmse:0.105519
# [2426]	validation_0-rmse:0.105522
# [2427]	validation_0-rmse:0.105525
# [2428]	validation_0-rmse:0.105521
# [2429]	validation_0-rmse:0.105524
# [2430]	validation_0-rmse:0.10553
# [2431]	validation_0-rmse:0.105533
# [2432]	validation_0-rmse:0.105523
# [2433]	validation_0-rmse:0.105519
# [2434]	validation_0-rmse:0.105524
# [2435]	validation_0-rmse:0.105535
# [2436]	validation_0-rmse:0.10554
# [2437]	validation_0-rmse:0.10554
# [2438]	validation_0-rmse:0.105542
# [2439]	validation_0-rmse:0.105537
# [2440]	validation_0-rmse:0.105521
# [2441]	validation_0-rmse:0.105506
# [2442]	validation_0-rmse:0.105506
# [2443]	validation_0-rmse:0.105515
# [2444]	validation_0-rmse:0.105512
# [2445]	validation_0-rmse:0.105504
# [2446]	validation_0-rmse:0.105515
# [2447]	validation_0-rmse:0.105519
# [2448]	validation_0-rmse:0.105517
# [2449]	validation_0-rmse:0.105523
# [2450]	validation_0-rmse:0.105525
# [2451]	validation_0-rmse:0.105516
# [2452]	validation_0-rmse:0.105513
# [2453]	validation_0-rmse:0.105515
# [2454]	validation_0-rmse:0.105514
# [2455]	validation_0-rmse:0.105497
# [2456]	validation_0-rmse:0.1055
# [2457]	validation_0-rmse:0.1055
# [2458]	validation_0-rmse:0.105509
# [2459]	validation_0-rmse:0.105505
# [2460]	validation_0-rmse:0.105523
# [2461]	validation_0-rmse:0.105514
# [2462]	validation_0-rmse:0.105518
# [2463]	validation_0-rmse:0.10551
# [2464]	validation_0-rmse:0.10551
# [2465]	validation_0-rmse:0.105484
# [2466]	validation_0-rmse:0.105477
# [2467]	validation_0-rmse:0.10546
# [2468]	validation_0-rmse:0.105457
# [2469]	validation_0-rmse:0.105459
# [2470]	validation_0-rmse:0.105456
# [2471]	validation_0-rmse:0.105448
# [2472]	validation_0-rmse:0.105452
# [2473]	validation_0-rmse:0.105457
# [2474]	validation_0-rmse:0.105457
# [2475]	validation_0-rmse:0.105458
# [2476]	validation_0-rmse:0.105446
# [2477]	validation_0-rmse:0.105458
# [2478]	validation_0-rmse:0.105451
# [2479]	validation_0-rmse:0.105454
# [2480]	validation_0-rmse:0.105455
# [2481]	validation_0-rmse:0.105457
# [2482]	validation_0-rmse:0.105456
# [2483]	validation_0-rmse:0.105463
# [2484]	validation_0-rmse:0.105451
# [2485]	validation_0-rmse:0.105449
# [2486]	validation_0-rmse:0.105446
# [2487]	validation_0-rmse:0.105448
# [2488]	validation_0-rmse:0.105464
# [2489]	validation_0-rmse:0.10546
# [2490]	validation_0-rmse:0.105469
# [2491]	validation_0-rmse:0.105467
# [2492]	validation_0-rmse:0.105478
# [2493]	validation_0-rmse:0.105475
# [2494]	validation_0-rmse:0.10547
# [2495]	validation_0-rmse:0.105472
# [2496]	validation_0-rmse:0.105485
# [2497]	validation_0-rmse:0.105516
# [2498]	validation_0-rmse:0.1055
# [2499]	validation_0-rmse:0.105496
# [2500]	validation_0-rmse:0.10548
# [2501]	validation_0-rmse:0.105494
# [2502]	validation_0-rmse:0.105488
# [2503]	validation_0-rmse:0.105489
# [2504]	validation_0-rmse:0.105472
# [2505]	validation_0-rmse:0.105483
# [2506]	validation_0-rmse:0.105489
# [2507]	validation_0-rmse:0.105488
# [2508]	validation_0-rmse:0.105485
# [2509]	validation_0-rmse:0.105475
# [2510]	validation_0-rmse:0.105466
# [2511]	validation_0-rmse:0.105473
# [2512]	validation_0-rmse:0.105469
# [2513]	validation_0-rmse:0.105458
# [2514]	validation_0-rmse:0.105466
# [2515]	validation_0-rmse:0.105452
# [2516]	validation_0-rmse:0.105454
# [2517]	validation_0-rmse:0.105443
# [2518]	validation_0-rmse:0.105443
# [2519]	validation_0-rmse:0.105445
# [2520]	validation_0-rmse:0.10545
# [2521]	validation_0-rmse:0.105456
# [2522]	validation_0-rmse:0.105474
# [2523]	validation_0-rmse:0.105479
# [2524]	validation_0-rmse:0.105476
# [2525]	validation_0-rmse:0.105481
# [2526]	validation_0-rmse:0.105479
# [2527]	validation_0-rmse:0.105481
# [2528]	validation_0-rmse:0.10548
# [2529]	validation_0-rmse:0.105467
# [2530]	validation_0-rmse:0.105466
# [2531]	validation_0-rmse:0.10546
# [2532]	validation_0-rmse:0.105448
# [2533]	validation_0-rmse:0.105449
# [2534]	validation_0-rmse:0.10545
# [2535]	validation_0-rmse:0.105445
# [2536]	validation_0-rmse:0.105445
# [2537]	validation_0-rmse:0.105444
# [2538]	validation_0-rmse:0.105451
# [2539]	validation_0-rmse:0.105455
# [2540]	validation_0-rmse:0.105458
# [2541]	validation_0-rmse:0.105451
# [2542]	validation_0-rmse:0.105444
# [2543]	validation_0-rmse:0.105454
# [2544]	validation_0-rmse:0.105464
# [2545]	validation_0-rmse:0.10545
# [2546]	validation_0-rmse:0.105469
# [2547]	validation_0-rmse:0.105468
# [2548]	validation_0-rmse:0.105469
# [2549]	validation_0-rmse:0.105474
# [2550]	validation_0-rmse:0.105474
# [2551]	validation_0-rmse:0.105509
# [2552]	validation_0-rmse:0.10551
# [2553]	validation_0-rmse:0.105507
# [2554]	validation_0-rmse:0.105503
# [2555]	validation_0-rmse:0.105502
# [2556]	validation_0-rmse:0.105498
# [2557]	validation_0-rmse:0.105496
# [2558]	validation_0-rmse:0.105483
# [2559]	validation_0-rmse:0.10547
# [2560]	validation_0-rmse:0.105464
# [2561]	validation_0-rmse:0.105458
# [2562]	validation_0-rmse:0.10546
# [2563]	validation_0-rmse:0.105465
# [2564]	validation_0-rmse:0.105465
# [2565]	validation_0-rmse:0.105461
# [2566]	validation_0-rmse:0.105457
# [2567]	validation_0-rmse:0.105461
# [2568]	validation_0-rmse:0.105451
# [2569]	validation_0-rmse:0.105448
# [2570]	validation_0-rmse:0.105438
# [2571]	validation_0-rmse:0.105437
# [2572]	validation_0-rmse:0.10543
# [2573]	validation_0-rmse:0.105422
# [2574]	validation_0-rmse:0.105432
# [2575]	validation_0-rmse:0.105432
# [2576]	validation_0-rmse:0.105426
# [2577]	validation_0-rmse:0.105427
# [2578]	validation_0-rmse:0.105437
# [2579]	validation_0-rmse:0.105439
# [2580]	validation_0-rmse:0.105443
# [2581]	validation_0-rmse:0.105441
# [2582]	validation_0-rmse:0.105449
# [2583]	validation_0-rmse:0.105448
# [2584]	validation_0-rmse:0.105442
# [2585]	validation_0-rmse:0.105451
# [2586]	validation_0-rmse:0.10545
# [2587]	validation_0-rmse:0.105446
# [2588]	validation_0-rmse:0.105449
# [2589]	validation_0-rmse:0.105453
# [2590]	validation_0-rmse:0.10545
# [2591]	validation_0-rmse:0.105459
# [2592]	validation_0-rmse:0.105465
# [2593]	validation_0-rmse:0.105478
# [2594]	validation_0-rmse:0.105491
# [2595]	validation_0-rmse:0.105482
# [2596]	validation_0-rmse:0.105483
# [2597]	validation_0-rmse:0.105492
# [2598]	validation_0-rmse:0.105487
# [2599]	validation_0-rmse:0.105489
# [2600]	validation_0-rmse:0.105488
# [2601]	validation_0-rmse:0.105484
# [2602]	validation_0-rmse:0.105508
# [2603]	validation_0-rmse:0.105505
# [2604]	validation_0-rmse:0.105507
# [2605]	validation_0-rmse:0.1055
# [2606]	validation_0-rmse:0.105497
# [2607]	validation_0-rmse:0.105498
# [2608]	validation_0-rmse:0.105513
# [2609]	validation_0-rmse:0.105512
# [2610]	validation_0-rmse:0.105523
# [2611]	validation_0-rmse:0.105515
# [2612]	validation_0-rmse:0.105524
# [2613]	validation_0-rmse:0.105518
# [2614]	validation_0-rmse:0.105512
# [2615]	validation_0-rmse:0.10551
# [2616]	validation_0-rmse:0.105519
# [2617]	validation_0-rmse:0.105517
# [2618]	validation_0-rmse:0.105516
# [2619]	validation_0-rmse:0.105505
# [2620]	validation_0-rmse:0.105498
# [2621]	validation_0-rmse:0.105492
# [2622]	validation_0-rmse:0.10551
# [2623]	validation_0-rmse:0.105506
# [2624]	validation_0-rmse:0.105501
# [2625]	validation_0-rmse:0.105509
# [2626]	validation_0-rmse:0.10551
# [2627]	validation_0-rmse:0.10552
# [2628]	validation_0-rmse:0.105532
# [2629]	validation_0-rmse:0.105535
# [2630]	validation_0-rmse:0.105533
# [2631]	validation_0-rmse:0.10552
# [2632]	validation_0-rmse:0.105523
# [2633]	validation_0-rmse:0.105527
# [2634]	validation_0-rmse:0.105531
# [2635]	validation_0-rmse:0.105527
# [2636]	validation_0-rmse:0.105519
# [2637]	validation_0-rmse:0.105521
# [2638]	validation_0-rmse:0.105521
# [2639]	validation_0-rmse:0.105526
# [2640]	validation_0-rmse:0.105524
# [2641]	validation_0-rmse:0.105517
# [2642]	validation_0-rmse:0.105506
# [2643]	validation_0-rmse:0.105504
# [2644]	validation_0-rmse:0.10551
# [2645]	validation_0-rmse:0.105502
# [2646]	validation_0-rmse:0.105498
# [2647]	validation_0-rmse:0.105497
# [2648]	validation_0-rmse:0.105502
# [2649]	validation_0-rmse:0.105495
# [2650]	validation_0-rmse:0.105481
# [2651]	validation_0-rmse:0.105477
# [2652]	validation_0-rmse:0.105472
# [2653]	validation_0-rmse:0.105475
# [2654]	validation_0-rmse:0.105469
# [2655]	validation_0-rmse:0.105467
# [2656]	validation_0-rmse:0.105463
# [2657]	validation_0-rmse:0.10546
# [2658]	validation_0-rmse:0.105469
# [2659]	validation_0-rmse:0.10547
# [2660]	validation_0-rmse:0.105476
# [2661]	validation_0-rmse:0.105481
# [2662]	validation_0-rmse:0.105467
# [2663]	validation_0-rmse:0.105448
# [2664]	validation_0-rmse:0.105442
# [2665]	validation_0-rmse:0.105442
# [2666]	validation_0-rmse:0.10543
# [2667]	validation_0-rmse:0.105435
# [2668]	validation_0-rmse:0.105431
# [2669]	validation_0-rmse:0.105438
# [2670]	validation_0-rmse:0.105435
# [2671]	validation_0-rmse:0.105433
# [2672]	validation_0-rmse:0.105429
# [2673]	validation_0-rmse:0.105426
# Stopping. Best iteration:
# [2573]	validation_0-rmse:0.105422
#
# Duration: 16.058723211288452s

# %%
figsize=(40,40)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
predictions = model.predict(norm_sub[normed_test_data.columns])
predictions = np.floor(np.exp(predictions))

# %%
predictions
# Out:
# array([124288., 163161., 186873., ..., 168141., 115315., 219939.],
#       dtype=float32)

# %%
my_submission = pd.DataFrame({'Id': df_test.index, 'SalePrice': predictions})
my_submission.to_csv('submission.csv', index=False)

# %%
my_submission.head()
# Out:
#      Id  SalePrice
# 0  1461   124288.0
# 1  1462   163161.0
# 2  1463   186873.0
# 3  1464   194277.0
# 4  1465   180086.0

# %%
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([10,plt.xlim()[1]])
plt.ylim([10,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %%
results = cross_val_score(model, , cv=kfold)
