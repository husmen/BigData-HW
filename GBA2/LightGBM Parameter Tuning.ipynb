# %% [markdown]
# # Fine Tuning XGBoost Parameters
# This kernel will try to introduce you to regression with XGBoost and how to fine-tune its parameters for better results.
#
# The following kernels were a huge help and I took some code snippets from them:
# - [Regression to Predict House Prices by Elie Kawerk](https://www.kaggle.com/eliekawerk/regression-to-predict-house-prices)
# - [Blending of 6 Models (Top 4%) by Sandeep Kumar](https://www.kaggle.com/sandeepkumar121995/blending-of-6-models-top-10)
# - [Regularized Linear Models by Alexandru Papiu](https://www.kaggle.com/apapiu/regularized-linear-models)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

#plotting
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("whitegrid")

#ML
from sklearn.model_selection import KFold, GridSearchCV, cross_val_score, train_test_split # Model evaluation
from lightgbm import LGBMRegressor, plot_importance # LGBM

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import datetime
import time
import os
#print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.

# %%
# Load data and display info dataset
#df_train = pd.read_csv("../input/train.csv", index_col = 0) 
#df_test = pd.read_csv("../input/test.csv", index_col = 0) 

df_train = pd.read_csv("~/datasets/HP-ART//train.csv", index_col = 0) 
df_test = pd.read_csv("~/datasets/HP-ART//test.csv", index_col = 0)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB

# %% [markdown]
# # Preprocessing

# %%
#display Missing values
label_nas = []
for col in df_train.columns.tolist():
    if np.sum(df_train[col].isnull() ) != 0:
        label_nas.append(col)
    else:
        label_nas.append("")

plt.figure(figsize=(12,7))
plt.suptitle('Missing Values in the Training Set')
sns.heatmap(df_train.isnull(), yticklabels=False, xticklabels=label_nas ,cbar = False, cmap='viridis')
plt.show()

# %%
#remove columns with too many missed values
null_values_per_col = np.sum(df_train.drop(["SalePrice"], axis=1).isnull(), axis=0)
max_na = int(df_train.shape[0]/3.0) #allowing up to 1/3 of the data to be missing
cols_to_remove = []

for col in df_train.drop(["SalePrice"],axis=1).columns.tolist():
    if null_values_per_col[col] > max_na: 
        cols_to_remove.append(col)
        df_train.drop(col, axis=1, inplace=True)
        
print("New shape of the training set is: (%d,%d)" %df_train.shape)        
print("The removed columns are: " + str(cols_to_remove))

#do the same for test dataset
df_test.drop(cols_to_remove, axis=1, inplace=True)
# Out:
# New shape of the training set is: (1460,75)
# The removed columns are: ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
#remap some columns to have numerical data
rep_map_1 = {"NA": 0, "Po": 1,
             "Fa": 2, "TA": 3, 
             "Gd": 4, "Ex": 5,}

rep_map_2 = {"NA": 0, "No": 1,
             "Mn": 2, "Av": 3, 
             "Gd": 4,}

rep_map_3 = {"NA": 0, "Unf": 1,
             "LwQ": 2, "Rec": 3, 
             "BLQ": 4, "ALQ": 5,
             "GLQ": 6,}

rep_map_4 = {"NA": 0, "MnWw": 1,
             "GdWo": 2, "MnPrv": 3, 
             "GdPrv": 4,}

scale_list_1 = ["ExterCond", "BsmtCond", "HeatingQC", "KitchenQual", "GarageCond"]
scale_list_2 = ["BsmtFinType1"]
scale_list_3 = ["BsmtFinType2"]
scale_list_4 = ["Fence"]

# %%
for s in scale_list_1:
    df_train = df_train.replace({s:rep_map_1,})
    df_test = df_test.replace({s:rep_map_1,})

df_train = df_train.replace({scale_list_2[0]:rep_map_2,
                             scale_list_3[0]:rep_map_3,
                             scale_list_4[0]:rep_map_4,})

df_test = df_test.replace({scale_list_2[0]:rep_map_2,
                             scale_list_3[0]:rep_map_3,
                             scale_list_4[0]:rep_map_4,})

# %%
#Correlation matrix
corr_mat = df_train.drop(columns=["SalePrice"]).corr().abs()

# %%
#Plot the heatmap with seaborn
plt.figure(figsize=(25,25)) 
sns.heatmap(corr_mat, 
        xticklabels=corr_mat.columns,
        yticklabels=corr_mat.columns)

# %%
#List the highly correlated columns
corr_tmp = corr_mat.unstack()
corr_tmp = corr_tmp.sort_values(kind="quicksort")

print(corr_tmp[-len(corr_mat)-20:-len(corr_mat)])
# Out:
# YearRemodAdd  GarageYrBlt     0.642277
# GarageYrBlt   YearRemodAdd    0.642277
# BsmtFullBath  BsmtFinSF1      0.649212
# BsmtFinSF1    BsmtFullBath    0.649212
# KitchenQual   OverallQual     0.673331
# OverallQual   KitchenQual     0.673331
# BedroomAbvGr  TotRmsAbvGrd    0.676620
# TotRmsAbvGrd  BedroomAbvGr    0.676620
# 2ndFlrSF      GrLivArea       0.687501
# GrLivArea     2ndFlrSF        0.687501
# BsmtFinSF2    BsmtFinType2    0.805212
# BsmtFinType2  BsmtFinSF2      0.805212
# TotalBsmtSF   1stFlrSF        0.819530
# 1stFlrSF      TotalBsmtSF     0.819530
# GrLivArea     TotRmsAbvGrd    0.825489
# TotRmsAbvGrd  GrLivArea       0.825489
# GarageYrBlt   YearBuilt       0.825667
# YearBuilt     GarageYrBlt     0.825667
# GarageCars    GarageArea      0.882475
# GarageArea    GarageCars      0.882475
# dtype: float64

# %%
#Remove highly correlated columns if needed, I will skip that
rm_corr = False
if rm_corr:
    columns_corr = ["GarageYrBlt", "GarageCars", "GrLivArea"]
    df_train = df_train.drop(columns=columns_corr)
    df_test = df_test.drop(columns=columns_corr)

# %%
#Get a list of all categorical features
categorical_list = []

for col in df_train.columns.tolist():
    if df_train[col].dtype == 'object':
        categorical_list.append(col)

# %%
#Convert categorical variables into dummy/indicator variables
df_train = pd.get_dummies(df_train, columns=categorical_list)
df_test = pd.get_dummies(df_test, columns=categorical_list)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Columns: 251 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(5), int64(37), uint8(209)
# memory usage: 788.5 KB

# %%
#If you chose to leave out some columns, remove them now
for col in df_train.columns.tolist():
    if df_train[col].dtype == 'object':
        del df_train[col]
        del df_test[col]
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 1 to 1460
# Columns: 251 entries, MSSubClass to SaleCondition_Partial
# dtypes: float64(5), int64(37), uint8(209)
# memory usage: 788.5 KB

# %%
#Check the skewness of SalePrice
skewness = df_train['SalePrice'].skew()
df_train['SalePrice'].plot.hist(edgecolor='white', bins=30, 
                                label='SalePrice skew =' + str(round(skewness,2)))
plt.suptitle("SalePrice distribution")
plt.legend()
plt.show()

# %%
#Apply log1p to reduce skewness
skewness = np.log1p(df_train['SalePrice']).skew()
np.log(df_train['SalePrice']).plot.hist(edgecolor='white', bins=30, 
                                label='SalePrice skew =' + str(round(skewness,2)))
plt.suptitle("SalePrice distribution")
plt.legend()
plt.show()

del skewness

# %%
train_stats = df_train.describe()
train_stats
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  1460.000000  1201.000000    1460.000000  1460.000000  1460.000000
# mean     56.897260    70.049958   10516.828082     6.099315     5.575342
# std      42.300571    24.284752    9981.264932     1.382997     1.112799
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7553.500000     5.000000     5.000000
# 50%      50.000000    69.000000    9478.500000     6.000000     5.000000
# 75%      70.000000    80.000000   11601.500000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea    ExterCond   BsmtFinSF1  ...  \
# count  1460.000000   1460.000000  1452.000000  1460.000000  1460.000000  ...
# mean   1971.267808   1984.865753   103.685262     3.083562   443.639726  ...
# std      30.202904     20.645407   181.066207     0.351054   456.098091  ...
# min    1872.000000   1950.000000     0.000000     1.000000     0.000000  ...
# 25%    1954.000000   1967.000000     0.000000     3.000000     0.000000  ...
# 50%    1973.000000   1994.000000     0.000000     3.000000   383.500000  ...
# 75%    2000.000000   2004.000000   166.000000     3.000000   712.250000  ...
# max    2010.000000   2010.000000  1600.000000     5.000000  5644.000000  ...
#
#        SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# count     1460.000000   1460.000000   1460.000000  1460.000000
# mean         0.003425      0.083562      0.002055     0.867808
# std          0.058440      0.276824      0.045299     0.338815
# min          0.000000      0.000000      0.000000     0.000000
# 25%          0.000000      0.000000      0.000000     1.000000
# 50%          0.000000      0.000000      0.000000     1.000000
# 75%          0.000000      0.000000      0.000000     1.000000
# max          1.000000      1.000000      1.000000     1.000000
#
#        SaleCondition_Abnorml  SaleCondition_AdjLand  SaleCondition_Alloca  \
# count            1460.000000            1460.000000           1460.000000
# mean                0.069178               0.002740              0.008219
# std                 0.253844               0.052289              0.090317
# min                 0.000000               0.000000              0.000000
# 25%                 0.000000               0.000000              0.000000
# 50%                 0.000000               0.000000              0.000000
# 75%                 0.000000               0.000000              0.000000
# max                 1.000000               1.000000              1.000000
#
#        SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial
# count           1460.000000           1460.000000            1460.000000
# mean               0.013699              0.820548               0.085616
# std                0.116277              0.383862               0.279893
# min                0.000000              0.000000               0.000000
# 25%                0.000000              1.000000               0.000000
# 50%                0.000000              1.000000               0.000000
# 75%                0.000000              1.000000               0.000000
# max                1.000000              1.000000               1.000000
#
# [8 rows x 251 columns]

# %%
#prepare for splitting and normalization
df_train['SalePrice'] = np.log1p(df_train['SalePrice'])
df_train_tmp = df_train.drop(columns=["SalePrice"]) #Normalize across the whole training dataset

def norm(x):
    #return (x - train_stats['mean']) / train_stats['std']
    return (x - df_train_tmp.mean()) / (df_train_tmp.max() - df_train_tmp.min())

# %%
#Normalise, split Z and Y, split data into 80% training and 20% validation set
y_full = df_train.pop('SalePrice')
X_full = norm(df_train)
X_test = norm(df_test)

X_train, X_val, y_train, y_val = train_test_split(X_full, y_full, test_size=0.2, random_state=123)

# %% [markdown]
# # Parameter Tuning

# %%
#Cross validation
kfold = KFold(n_splits=5, shuffle=True, random_state=123)
#Function to quickly recreate the model when needed
def model_eval():
    model = XGBRegressor(learning_rate=0.01, #dflt 0.1
                         verbosity = 3, 
                         objective='reg:linear',
                         n_jobs=-1,
                         subsample=0.7,
                         colsample_bytree=0.35,
                         approx='gpu_hist', #use GPU instead of CPU if available
                         random_state=123)
    return model

# %%
# 1: optimise n_estimators and max_depth
# the range to explore depends on the problem, and your observations while trying 
# for the meaning of each parameter, check the official documentation https://xgboost.readthedocs.io/en/latest/parameter.html
n_estimators = range(4000, 8001, 500)
max_depth = range(4,7,2)
# create dictionary with the parameters
param_grid = dict(max_depth=max_depth, n_estimators=n_estimators)
print("number of combinations: {}".format(len(n_estimators)*len(max_depth)))
# Out:
# number of combinations: 18

# %%
#fine tune the model
model = model_eval()
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
grid_result = grid_search.fit(X_full, y_full)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed: 10.4min finished
# /home/husmen/miniconda3/envs/tf2/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/husmen/miniconda3/envs/tf2/lib/python3.7/site-packages/xgboost/core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.014277 using {'max_depth': 4, 'n_estimators': 6000}
# -0.014317 (0.002057) with: {'max_depth': 4, 'n_estimators': 4000}
# -0.014306 (0.002052) with: {'max_depth': 4, 'n_estimators': 4500}
# -0.014291 (0.002043) with: {'max_depth': 4, 'n_estimators': 5000}
# -0.014279 (0.002036) with: {'max_depth': 4, 'n_estimators': 5500}
# -0.014277 (0.002038) with: {'max_depth': 4, 'n_estimators': 6000}
# -0.014284 (0.002038) with: {'max_depth': 4, 'n_estimators': 6500}
# -0.014281 (0.002042) with: {'max_depth': 4, 'n_estimators': 7000}
# -0.014283 (0.002037) with: {'max_depth': 4, 'n_estimators': 7500}
# -0.014286 (0.002038) with: {'max_depth': 4, 'n_estimators': 8000}
# -0.014814 (0.001856) with: {'max_depth': 6, 'n_estimators': 4000}
# -0.014811 (0.001853) with: {'max_depth': 6, 'n_estimators': 4500}
# -0.014811 (0.001853) with: {'max_depth': 6, 'n_estimators': 5000}
# -0.014811 (0.001852) with: {'max_depth': 6, 'n_estimators': 5500}
# -0.014812 (0.001850) with: {'max_depth': 6, 'n_estimators': 6000}
# -0.014811 (0.001850) with: {'max_depth': 6, 'n_estimators': 6500}
# -0.014812 (0.001850) with: {'max_depth': 6, 'n_estimators': 7000}
# -0.014813 (0.001850) with: {'max_depth': 6, 'n_estimators': 7500}
# -0.014813 (0.001850) with: {'max_depth': 6, 'n_estimators': 8000}

# %%
# plot results
scores = np.array(means).reshape(len(max_depth), len(n_estimators))
for i, value in enumerate(max_depth):
    plt.plot(n_estimators, scores[i], label='depth: ' + str(value))
plt.legend()
plt.title("XGBoost n_estimators vs max_depth")
plt.xlabel('n_estimators')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
#plot n_estimators with its standard deviation
scores_1 = np.array(means).reshape(len(max_depth), len(n_estimators))
scores_2 = np.array(stds).reshape(len(max_depth), len(n_estimators))

plt.errorbar(n_estimators, scores_1[1], yerr=scores_2[1])
plt.title("XGBoost n_estimators vs -MSE")
plt.xlabel('n_estimators')
plt.ylabel('MSE')
# Out:
# Text(0, 0.5, 'MSE')

# %%
# 2: add min_child_weight parameter
# we could have done this from the beginning, but I wanted to show some graphs above first
n_estimators = [6000]
max_depth = [3, 4]
min_child_weight = range(2, 4, 1)
param_grid = dict(max_depth=max_depth, n_estimators=n_estimators, min_child_weight=min_child_weight)
print("number of combinations: {}".format(len(n_estimators)*len(max_depth)*len(min_child_weight)))
# Out:
# number of combinations: 4

# %%
model = model_eval()
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
grid_result = grid_search.fit(X_full, y_full)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  20 | elapsed:  1.6min remaining:  1.1min
# [Parallel(n_jobs=-1)]: Done  20 out of  20 | elapsed:  2.1min finished

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.014063 using {'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 6000}
# -0.014091 (0.001813) with: {'max_depth': 3, 'min_child_weight': 2, 'n_estimators': 6000}
# -0.014063 (0.001731) with: {'max_depth': 3, 'min_child_weight': 3, 'n_estimators': 6000}
# -0.014322 (0.001777) with: {'max_depth': 4, 'min_child_weight': 2, 'n_estimators': 6000}
# -0.014153 (0.001680) with: {'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000}

# %%
# 3: add gamma, reg_alpha and reg_lambda, 
n_estimators = [6000]
max_depth = [4]
min_child_weight = [3]
gamma = np.arange(0, 0.00001, 0.00002)
reg_alpha = np.arange(0.00000, 0.00011, 0.00002)
reg_lambda= np.arange(1, 0.99989, -0.00002)

param_grid = dict(n_estimators = n_estimators, max_depth = max_depth, min_child_weight = min_child_weight,
                  gamma = gamma, reg_alpha=reg_alpha, reg_lambda=reg_lambda)
print("number of combinations: {}".format(len(gamma)*len(reg_alpha)*len(reg_lambda)))
# Out:
# number of combinations: 36

# %%
model = model_eval()
grid_search = GridSearchCV(model, param_grid, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
grid_result = grid_search.fit(X_full, y_full)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed: 23.1min finished

# %%
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: -0.014269 using {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 0.99998}
# -0.014349 (0.001643) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0, 'reg_lambda': 1.0}
# -0.014340 (0.001642) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0, 'reg_lambda': 0.99998}
# -0.014310 (0.001623) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0, 'reg_lambda': 0.99996}
# -0.014315 (0.001626) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0, 'reg_lambda': 0.9999399999999999}
# -0.014333 (0.001618) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0, 'reg_lambda': 0.9999199999999999}
# -0.014341 (0.001618) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0, 'reg_lambda': 0.9998999999999999}
# -0.014358 (0.001620) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 2e-05, 'reg_lambda': 1.0}
# -0.014330 (0.001632) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 2e-05, 'reg_lambda': 0.99998}
# -0.014323 (0.001654) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 2e-05, 'reg_lambda': 0.99996}
# -0.014357 (0.001624) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 2e-05, 'reg_lambda': 0.9999399999999999}
# -0.014347 (0.001673) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 2e-05, 'reg_lambda': 0.9999199999999999}
# -0.014350 (0.001640) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 2e-05, 'reg_lambda': 0.9998999999999999}
# -0.014331 (0.001647) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 4e-05, 'reg_lambda': 1.0}
# -0.014355 (0.001624) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 4e-05, 'reg_lambda': 0.99998}
# -0.014345 (0.001646) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 4e-05, 'reg_lambda': 0.99996}
# -0.014360 (0.001650) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 4e-05, 'reg_lambda': 0.9999399999999999}
# -0.014349 (0.001664) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 4e-05, 'reg_lambda': 0.9999199999999999}
# -0.014347 (0.001633) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 4e-05, 'reg_lambda': 0.9998999999999999}
# -0.014360 (0.001653) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 1.0}
# -0.014269 (0.001650) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 0.99998}
# -0.014365 (0.001631) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 0.99996}
# -0.014322 (0.001599) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 0.9999399999999999}
# -0.014326 (0.001626) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 0.9999199999999999}
# -0.014314 (0.001668) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 6.000000000000001e-05, 'reg_lambda': 0.9998999999999999}
# -0.014369 (0.001616) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 8e-05, 'reg_lambda': 1.0}
# -0.014305 (0.001645) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 8e-05, 'reg_lambda': 0.99998}
# -0.014310 (0.001675) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 8e-05, 'reg_lambda': 0.99996}
# -0.014340 (0.001641) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 8e-05, 'reg_lambda': 0.9999399999999999}
# -0.014319 (0.001663) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 8e-05, 'reg_lambda': 0.9999199999999999}
# -0.014294 (0.001637) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 8e-05, 'reg_lambda': 0.9998999999999999}
# -0.014336 (0.001611) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0001, 'reg_lambda': 1.0}
# -0.014345 (0.001661) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0001, 'reg_lambda': 0.99998}
# -0.014311 (0.001672) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0001, 'reg_lambda': 0.99996}
# -0.014367 (0.001609) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0001, 'reg_lambda': 0.9999399999999999}
# -0.014299 (0.001661) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0001, 'reg_lambda': 0.9999199999999999}
# -0.014309 (0.001647) with: {'gamma': 0.0, 'max_depth': 4, 'min_child_weight': 3, 'n_estimators': 6000, 'reg_alpha': 0.0001, 'reg_lambda': 0.9998999999999999}

# %% [markdown]
# # Training

# %%
# final model with tuned parameters
model = LGBMRegressor(objective='regression',
                       num_leaves=31, #dflt 31
                       learning_rate=0.01,
                       n_estimators=2000,
                       max_bin = 63,
                       bagging_freq = 5,
                       bagging_fraction = 0.7, #subsample 0.8
                       feature_fraction = 0.35, #colsample_bytree 0.2319 
                       min_data_in_leaf = 6, #dflt = 20 
                       min_sum_hessian_in_leaf = 1, #min_child_weight, dflt 1e-3
                       device_type='cpu', #gpu was slower than cpu for some reason!
                       random_state=123)

# %%
# final Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=123)
results = cross_val_score(model, X_full, y_full, scoring="neg_mean_squared_error", n_jobs=-1, cv=kfold, verbose=3)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.8s remaining:    5.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.8s finished

# %%
# CV results
results_rmsle = np.sqrt(-results)
print("-MSE: {} ({})".format(results.mean(),results.std()))
print("RMS(L)E: {} ({})".format(results_rmsle.mean(),results_rmsle.std()))
# Out:
# -MSE: -0.015306084406297346 (0.0021997813200194385)
# RMS(L)E: 0.12339500352050559 (0.008930706157508479)

# %%
#Final training
tick=time.time()

fitted_model = model.fit(X_train, y_train,
                         eval_set=[(X_val, y_val)],
                         eval_metric='rmse', # Equivalent to RMSLE since we have log1p(SalePrice)
                         early_stopping_rounds=100,
                         verbose=True)

print("Duration: {}s".format(time.time()-tick))
# Out:
# [1]	valid_0's rmse: 0.382453	valid_0's l2: 0.146271
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's rmse: 0.379383	valid_0's l2: 0.143931
# [3]	valid_0's rmse: 0.376575	valid_0's l2: 0.141809
# [4]	valid_0's rmse: 0.373721	valid_0's l2: 0.139667
# [5]	valid_0's rmse: 0.370796	valid_0's l2: 0.13749
# [6]	valid_0's rmse: 0.368086	valid_0's l2: 0.135487
# [7]	valid_0's rmse: 0.3653	valid_0's l2: 0.133444
# [8]	valid_0's rmse: 0.362345	valid_0's l2: 0.131294
# [9]	valid_0's rmse: 0.359329	valid_0's l2: 0.129118
# [10]	valid_0's rmse: 0.356561	valid_0's l2: 0.127136
# [11]	valid_0's rmse: 0.353902	valid_0's l2: 0.125246
# [12]	valid_0's rmse: 0.351337	valid_0's l2: 0.123438
# [13]	valid_0's rmse: 0.349091	valid_0's l2: 0.121864
# [14]	valid_0's rmse: 0.346551	valid_0's l2: 0.120098
# [15]	valid_0's rmse: 0.344036	valid_0's l2: 0.11836
# [16]	valid_0's rmse: 0.341231	valid_0's l2: 0.116438
# [17]	valid_0's rmse: 0.338634	valid_0's l2: 0.114673
# [18]	valid_0's rmse: 0.336301	valid_0's l2: 0.113099
# [19]	valid_0's rmse: 0.333895	valid_0's l2: 0.111486
# [20]	valid_0's rmse: 0.331525	valid_0's l2: 0.109909
# [21]	valid_0's rmse: 0.329021	valid_0's l2: 0.108255
# [22]	valid_0's rmse: 0.326438	valid_0's l2: 0.106562
# [23]	valid_0's rmse: 0.324078	valid_0's l2: 0.105027
# [24]	valid_0's rmse: 0.321654	valid_0's l2: 0.103461
# [25]	valid_0's rmse: 0.319355	valid_0's l2: 0.101987
# [26]	valid_0's rmse: 0.31708	valid_0's l2: 0.10054
# [27]	valid_0's rmse: 0.314558	valid_0's l2: 0.098947
# [28]	valid_0's rmse: 0.312336	valid_0's l2: 0.0975536
# [29]	valid_0's rmse: 0.310492	valid_0's l2: 0.0964051
# [30]	valid_0's rmse: 0.308154	valid_0's l2: 0.0949586
# [31]	valid_0's rmse: 0.306018	valid_0's l2: 0.0936471
# [32]	valid_0's rmse: 0.304044	valid_0's l2: 0.0924426
# [33]	valid_0's rmse: 0.301772	valid_0's l2: 0.0910663
# [34]	valid_0's rmse: 0.299555	valid_0's l2: 0.0897332
# [35]	valid_0's rmse: 0.297447	valid_0's l2: 0.0884747
# [36]	valid_0's rmse: 0.295147	valid_0's l2: 0.0871118
# [37]	valid_0's rmse: 0.292922	valid_0's l2: 0.0858035
# [38]	valid_0's rmse: 0.290968	valid_0's l2: 0.0846623
# [39]	valid_0's rmse: 0.289075	valid_0's l2: 0.0835645
# [40]	valid_0's rmse: 0.287059	valid_0's l2: 0.0824027
# [41]	valid_0's rmse: 0.285012	valid_0's l2: 0.0812319
# [42]	valid_0's rmse: 0.283116	valid_0's l2: 0.0801549
# [43]	valid_0's rmse: 0.281281	valid_0's l2: 0.0791188
# [44]	valid_0's rmse: 0.279492	valid_0's l2: 0.0781157
# [45]	valid_0's rmse: 0.277791	valid_0's l2: 0.0771679
# [46]	valid_0's rmse: 0.276	valid_0's l2: 0.0761759
# [47]	valid_0's rmse: 0.274319	valid_0's l2: 0.0752508
# [48]	valid_0's rmse: 0.272469	valid_0's l2: 0.0742396
# [49]	valid_0's rmse: 0.270731	valid_0's l2: 0.073295
# [50]	valid_0's rmse: 0.26917	valid_0's l2: 0.0724525
# [51]	valid_0's rmse: 0.267551	valid_0's l2: 0.0715833
# [52]	valid_0's rmse: 0.265765	valid_0's l2: 0.0706312
# [53]	valid_0's rmse: 0.263944	valid_0's l2: 0.0696665
# [54]	valid_0's rmse: 0.262242	valid_0's l2: 0.0687709
# [55]	valid_0's rmse: 0.260578	valid_0's l2: 0.067901
# [56]	valid_0's rmse: 0.258699	valid_0's l2: 0.0669253
# [57]	valid_0's rmse: 0.257139	valid_0's l2: 0.0661202
# [58]	valid_0's rmse: 0.255622	valid_0's l2: 0.0653426
# [59]	valid_0's rmse: 0.253948	valid_0's l2: 0.0644897
# [60]	valid_0's rmse: 0.252451	valid_0's l2: 0.0637315
# [61]	valid_0's rmse: 0.250732	valid_0's l2: 0.0628663
# [62]	valid_0's rmse: 0.249102	valid_0's l2: 0.062052
# [63]	valid_0's rmse: 0.2475	valid_0's l2: 0.0612561
# [64]	valid_0's rmse: 0.245898	valid_0's l2: 0.0604657
# [65]	valid_0's rmse: 0.244471	valid_0's l2: 0.0597662
# [66]	valid_0's rmse: 0.243016	valid_0's l2: 0.0590567
# [67]	valid_0's rmse: 0.241538	valid_0's l2: 0.0583405
# [68]	valid_0's rmse: 0.240164	valid_0's l2: 0.0576787
# [69]	valid_0's rmse: 0.238762	valid_0's l2: 0.0570073
# [70]	valid_0's rmse: 0.237303	valid_0's l2: 0.0563125
# [71]	valid_0's rmse: 0.235895	valid_0's l2: 0.0556465
# [72]	valid_0's rmse: 0.234493	valid_0's l2: 0.0549869
# [73]	valid_0's rmse: 0.233139	valid_0's l2: 0.0543537
# [74]	valid_0's rmse: 0.231729	valid_0's l2: 0.0536981
# [75]	valid_0's rmse: 0.230492	valid_0's l2: 0.0531265
# [76]	valid_0's rmse: 0.229228	valid_0's l2: 0.0525455
# [77]	valid_0's rmse: 0.227913	valid_0's l2: 0.0519443
# [78]	valid_0's rmse: 0.226675	valid_0's l2: 0.0513818
# [79]	valid_0's rmse: 0.225343	valid_0's l2: 0.0507793
# [80]	valid_0's rmse: 0.224219	valid_0's l2: 0.0502739
# [81]	valid_0's rmse: 0.222933	valid_0's l2: 0.0496991
# [82]	valid_0's rmse: 0.221667	valid_0's l2: 0.0491362
# [83]	valid_0's rmse: 0.220515	valid_0's l2: 0.0486268
# [84]	valid_0's rmse: 0.219303	valid_0's l2: 0.0480938
# [85]	valid_0's rmse: 0.218047	valid_0's l2: 0.0475445
# [86]	valid_0's rmse: 0.216884	valid_0's l2: 0.0470385
# [87]	valid_0's rmse: 0.215802	valid_0's l2: 0.0465704
# [88]	valid_0's rmse: 0.214565	valid_0's l2: 0.0460381
# [89]	valid_0's rmse: 0.213484	valid_0's l2: 0.0455753
# [90]	valid_0's rmse: 0.212289	valid_0's l2: 0.0450665
# [91]	valid_0's rmse: 0.211198	valid_0's l2: 0.0446047
# [92]	valid_0's rmse: 0.210011	valid_0's l2: 0.0441045
# [93]	valid_0's rmse: 0.208791	valid_0's l2: 0.0435936
# [94]	valid_0's rmse: 0.207753	valid_0's l2: 0.0431615
# [95]	valid_0's rmse: 0.206679	valid_0's l2: 0.0427161
# [96]	valid_0's rmse: 0.205564	valid_0's l2: 0.0422566
# [97]	valid_0's rmse: 0.204495	valid_0's l2: 0.0418183
# [98]	valid_0's rmse: 0.203552	valid_0's l2: 0.0414334
# [99]	valid_0's rmse: 0.202613	valid_0's l2: 0.041052
# [100]	valid_0's rmse: 0.20162	valid_0's l2: 0.0406505
# [101]	valid_0's rmse: 0.200554	valid_0's l2: 0.040222
# [102]	valid_0's rmse: 0.199573	valid_0's l2: 0.0398292
# [103]	valid_0's rmse: 0.198633	valid_0's l2: 0.0394551
# [104]	valid_0's rmse: 0.197707	valid_0's l2: 0.0390879
# [105]	valid_0's rmse: 0.196832	valid_0's l2: 0.038743
# [106]	valid_0's rmse: 0.195835	valid_0's l2: 0.0383515
# [107]	valid_0's rmse: 0.194854	valid_0's l2: 0.0379682
# [108]	valid_0's rmse: 0.193986	valid_0's l2: 0.0376307
# [109]	valid_0's rmse: 0.193097	valid_0's l2: 0.0372864
# [110]	valid_0's rmse: 0.192337	valid_0's l2: 0.0369933
# [111]	valid_0's rmse: 0.191479	valid_0's l2: 0.0366644
# [112]	valid_0's rmse: 0.190645	valid_0's l2: 0.0363456
# [113]	valid_0's rmse: 0.18974	valid_0's l2: 0.0360014
# [114]	valid_0's rmse: 0.188903	valid_0's l2: 0.0356844
# [115]	valid_0's rmse: 0.18812	valid_0's l2: 0.0353892
# [116]	valid_0's rmse: 0.18724	valid_0's l2: 0.0350588
# [117]	valid_0's rmse: 0.186397	valid_0's l2: 0.0347439
# [118]	valid_0's rmse: 0.185517	valid_0's l2: 0.0344167
# [119]	valid_0's rmse: 0.18459	valid_0's l2: 0.0340733
# [120]	valid_0's rmse: 0.18367	valid_0's l2: 0.0337348
# [121]	valid_0's rmse: 0.182891	valid_0's l2: 0.0334492
# [122]	valid_0's rmse: 0.182075	valid_0's l2: 0.0331514
# [123]	valid_0's rmse: 0.181281	valid_0's l2: 0.032863
# [124]	valid_0's rmse: 0.180432	valid_0's l2: 0.0325557
# [125]	valid_0's rmse: 0.179729	valid_0's l2: 0.0323024
# [126]	valid_0's rmse: 0.178999	valid_0's l2: 0.0320405
# [127]	valid_0's rmse: 0.178108	valid_0's l2: 0.0317224
# [128]	valid_0's rmse: 0.177201	valid_0's l2: 0.0314003
# [129]	valid_0's rmse: 0.176428	valid_0's l2: 0.0311268
# [130]	valid_0's rmse: 0.175578	valid_0's l2: 0.0308277
# [131]	valid_0's rmse: 0.174789	valid_0's l2: 0.0305513
# [132]	valid_0's rmse: 0.173909	valid_0's l2: 0.0302443
# [133]	valid_0's rmse: 0.173358	valid_0's l2: 0.0300529
# [134]	valid_0's rmse: 0.172598	valid_0's l2: 0.02979
# [135]	valid_0's rmse: 0.171875	valid_0's l2: 0.029541
# [136]	valid_0's rmse: 0.171153	valid_0's l2: 0.0292934
# [137]	valid_0's rmse: 0.170442	valid_0's l2: 0.0290503
# [138]	valid_0's rmse: 0.169812	valid_0's l2: 0.0288361
# [139]	valid_0's rmse: 0.169168	valid_0's l2: 0.0286177
# [140]	valid_0's rmse: 0.168596	valid_0's l2: 0.0284246
# [141]	valid_0's rmse: 0.167919	valid_0's l2: 0.0281969
# [142]	valid_0's rmse: 0.167192	valid_0's l2: 0.0279531
# [143]	valid_0's rmse: 0.166624	valid_0's l2: 0.0277637
# [144]	valid_0's rmse: 0.165917	valid_0's l2: 0.0275285
# [145]	valid_0's rmse: 0.165259	valid_0's l2: 0.0273106
# [146]	valid_0's rmse: 0.164644	valid_0's l2: 0.0271075
# [147]	valid_0's rmse: 0.16395	valid_0's l2: 0.0268795
# [148]	valid_0's rmse: 0.163281	valid_0's l2: 0.0266608
# [149]	valid_0's rmse: 0.162691	valid_0's l2: 0.0264683
# [150]	valid_0's rmse: 0.161984	valid_0's l2: 0.0262387
# [151]	valid_0's rmse: 0.161392	valid_0's l2: 0.0260475
# [152]	valid_0's rmse: 0.160817	valid_0's l2: 0.0258623
# [153]	valid_0's rmse: 0.160244	valid_0's l2: 0.0256781
# [154]	valid_0's rmse: 0.159683	valid_0's l2: 0.0254986
# [155]	valid_0's rmse: 0.159137	valid_0's l2: 0.0253247
# [156]	valid_0's rmse: 0.15861	valid_0's l2: 0.0251572
# [157]	valid_0's rmse: 0.158075	valid_0's l2: 0.0249878
# [158]	valid_0's rmse: 0.157509	valid_0's l2: 0.0248092
# [159]	valid_0's rmse: 0.157033	valid_0's l2: 0.0246594
# [160]	valid_0's rmse: 0.156533	valid_0's l2: 0.0245025
# [161]	valid_0's rmse: 0.155981	valid_0's l2: 0.0243301
# [162]	valid_0's rmse: 0.155476	valid_0's l2: 0.0241727
# [163]	valid_0's rmse: 0.154963	valid_0's l2: 0.0240136
# [164]	valid_0's rmse: 0.154389	valid_0's l2: 0.0238359
# [165]	valid_0's rmse: 0.153862	valid_0's l2: 0.0236736
# [166]	valid_0's rmse: 0.153463	valid_0's l2: 0.0235508
# [167]	valid_0's rmse: 0.15301	valid_0's l2: 0.023412
# [168]	valid_0's rmse: 0.15263	valid_0's l2: 0.0232958
# [169]	valid_0's rmse: 0.152266	valid_0's l2: 0.023185
# [170]	valid_0's rmse: 0.151859	valid_0's l2: 0.0230611
# [171]	valid_0's rmse: 0.151437	valid_0's l2: 0.0229333
# [172]	valid_0's rmse: 0.150988	valid_0's l2: 0.0227974
# [173]	valid_0's rmse: 0.150584	valid_0's l2: 0.0226755
# [174]	valid_0's rmse: 0.150242	valid_0's l2: 0.0225728
# [175]	valid_0's rmse: 0.149886	valid_0's l2: 0.0224657
# [176]	valid_0's rmse: 0.149594	valid_0's l2: 0.0223783
# [177]	valid_0's rmse: 0.149206	valid_0's l2: 0.0222625
# [178]	valid_0's rmse: 0.148833	valid_0's l2: 0.0221512
# [179]	valid_0's rmse: 0.148357	valid_0's l2: 0.0220098
# [180]	valid_0's rmse: 0.147936	valid_0's l2: 0.021885
# [181]	valid_0's rmse: 0.147466	valid_0's l2: 0.0217463
# [182]	valid_0's rmse: 0.147086	valid_0's l2: 0.0216343
# [183]	valid_0's rmse: 0.146659	valid_0's l2: 0.0215089
# [184]	valid_0's rmse: 0.146225	valid_0's l2: 0.0213817
# [185]	valid_0's rmse: 0.145739	valid_0's l2: 0.02124
# [186]	valid_0's rmse: 0.145379	valid_0's l2: 0.021135
# [187]	valid_0's rmse: 0.145052	valid_0's l2: 0.0210402
# [188]	valid_0's rmse: 0.144642	valid_0's l2: 0.0209214
# [189]	valid_0's rmse: 0.144379	valid_0's l2: 0.0208452
# [190]	valid_0's rmse: 0.144071	valid_0's l2: 0.0207564
# [191]	valid_0's rmse: 0.143625	valid_0's l2: 0.0206283
# [192]	valid_0's rmse: 0.143195	valid_0's l2: 0.0205047
# [193]	valid_0's rmse: 0.142742	valid_0's l2: 0.0203754
# [194]	valid_0's rmse: 0.14239	valid_0's l2: 0.0202748
# [195]	valid_0's rmse: 0.142077	valid_0's l2: 0.020186
# [196]	valid_0's rmse: 0.141728	valid_0's l2: 0.0200868
# [197]	valid_0's rmse: 0.141434	valid_0's l2: 0.0200036
# [198]	valid_0's rmse: 0.141121	valid_0's l2: 0.0199151
# [199]	valid_0's rmse: 0.140836	valid_0's l2: 0.0198347
# [200]	valid_0's rmse: 0.140449	valid_0's l2: 0.0197259
# [201]	valid_0's rmse: 0.140215	valid_0's l2: 0.0196601
# [202]	valid_0's rmse: 0.13987	valid_0's l2: 0.0195635
# [203]	valid_0's rmse: 0.139566	valid_0's l2: 0.0194788
# [204]	valid_0's rmse: 0.139281	valid_0's l2: 0.0193991
# [205]	valid_0's rmse: 0.139002	valid_0's l2: 0.0193215
# [206]	valid_0's rmse: 0.138678	valid_0's l2: 0.0192317
# [207]	valid_0's rmse: 0.13839	valid_0's l2: 0.0191518
# [208]	valid_0's rmse: 0.13808	valid_0's l2: 0.019066
# [209]	valid_0's rmse: 0.137713	valid_0's l2: 0.0189649
# [210]	valid_0's rmse: 0.137423	valid_0's l2: 0.018885
# [211]	valid_0's rmse: 0.13722	valid_0's l2: 0.0188293
# [212]	valid_0's rmse: 0.136913	valid_0's l2: 0.0187451
# [213]	valid_0's rmse: 0.136627	valid_0's l2: 0.018667
# [214]	valid_0's rmse: 0.13635	valid_0's l2: 0.0185913
# [215]	valid_0's rmse: 0.136149	valid_0's l2: 0.0185365
# [216]	valid_0's rmse: 0.135837	valid_0's l2: 0.0184517
# [217]	valid_0's rmse: 0.135649	valid_0's l2: 0.0184005
# [218]	valid_0's rmse: 0.135303	valid_0's l2: 0.018307
# [219]	valid_0's rmse: 0.135033	valid_0's l2: 0.018234
# [220]	valid_0's rmse: 0.134744	valid_0's l2: 0.018156
# [221]	valid_0's rmse: 0.134434	valid_0's l2: 0.0180725
# [222]	valid_0's rmse: 0.134238	valid_0's l2: 0.0180198
# [223]	valid_0's rmse: 0.133969	valid_0's l2: 0.0179477
# [224]	valid_0's rmse: 0.133735	valid_0's l2: 0.017885
# [225]	valid_0's rmse: 0.133426	valid_0's l2: 0.0178024
# [226]	valid_0's rmse: 0.133114	valid_0's l2: 0.0177194
# [227]	valid_0's rmse: 0.132895	valid_0's l2: 0.0176612
# [228]	valid_0's rmse: 0.132588	valid_0's l2: 0.0175795
# [229]	valid_0's rmse: 0.132391	valid_0's l2: 0.0175274
# [230]	valid_0's rmse: 0.132113	valid_0's l2: 0.0174538
# [231]	valid_0's rmse: 0.131858	valid_0's l2: 0.0173865
# [232]	valid_0's rmse: 0.131684	valid_0's l2: 0.0173407
# [233]	valid_0's rmse: 0.131456	valid_0's l2: 0.0172807
# [234]	valid_0's rmse: 0.131196	valid_0's l2: 0.0172124
# [235]	valid_0's rmse: 0.130954	valid_0's l2: 0.017149
# [236]	valid_0's rmse: 0.130746	valid_0's l2: 0.0170944
# [237]	valid_0's rmse: 0.130564	valid_0's l2: 0.0170469
# [238]	valid_0's rmse: 0.130345	valid_0's l2: 0.0169898
# [239]	valid_0's rmse: 0.130148	valid_0's l2: 0.0169384
# [240]	valid_0's rmse: 0.129928	valid_0's l2: 0.0168813
# [241]	valid_0's rmse: 0.129712	valid_0's l2: 0.0168251
# [242]	valid_0's rmse: 0.129495	valid_0's l2: 0.016769
# [243]	valid_0's rmse: 0.129275	valid_0's l2: 0.0167119
# [244]	valid_0's rmse: 0.12909	valid_0's l2: 0.0166642
# [245]	valid_0's rmse: 0.128884	valid_0's l2: 0.0166112
# [246]	valid_0's rmse: 0.12868	valid_0's l2: 0.0165584
# [247]	valid_0's rmse: 0.128535	valid_0's l2: 0.0165212
# [248]	valid_0's rmse: 0.128309	valid_0's l2: 0.0164631
# [249]	valid_0's rmse: 0.128129	valid_0's l2: 0.016417
# [250]	valid_0's rmse: 0.127949	valid_0's l2: 0.0163709
# [251]	valid_0's rmse: 0.12778	valid_0's l2: 0.0163276
# [252]	valid_0's rmse: 0.12754	valid_0's l2: 0.0162664
# [253]	valid_0's rmse: 0.127388	valid_0's l2: 0.0162277
# [254]	valid_0's rmse: 0.127181	valid_0's l2: 0.016175
# [255]	valid_0's rmse: 0.126992	valid_0's l2: 0.016127
# [256]	valid_0's rmse: 0.126788	valid_0's l2: 0.0160751
# [257]	valid_0's rmse: 0.126545	valid_0's l2: 0.0160136
# [258]	valid_0's rmse: 0.126373	valid_0's l2: 0.0159702
# [259]	valid_0's rmse: 0.126283	valid_0's l2: 0.0159475
# [260]	valid_0's rmse: 0.126051	valid_0's l2: 0.0158889
# [261]	valid_0's rmse: 0.125894	valid_0's l2: 0.0158493
# [262]	valid_0's rmse: 0.125727	valid_0's l2: 0.0158072
# [263]	valid_0's rmse: 0.125569	valid_0's l2: 0.0157675
# [264]	valid_0's rmse: 0.125435	valid_0's l2: 0.015734
# [265]	valid_0's rmse: 0.125214	valid_0's l2: 0.0156785
# [266]	valid_0's rmse: 0.125016	valid_0's l2: 0.0156291
# [267]	valid_0's rmse: 0.124846	valid_0's l2: 0.0155865
# [268]	valid_0's rmse: 0.124716	valid_0's l2: 0.0155542
# [269]	valid_0's rmse: 0.124538	valid_0's l2: 0.0155098
# [270]	valid_0's rmse: 0.12441	valid_0's l2: 0.015478
# [271]	valid_0's rmse: 0.124214	valid_0's l2: 0.0154292
# [272]	valid_0's rmse: 0.12405	valid_0's l2: 0.0153884
# [273]	valid_0's rmse: 0.123954	valid_0's l2: 0.0153647
# [274]	valid_0's rmse: 0.123816	valid_0's l2: 0.0153304
# [275]	valid_0's rmse: 0.123663	valid_0's l2: 0.0152926
# [276]	valid_0's rmse: 0.12356	valid_0's l2: 0.0152672
# [277]	valid_0's rmse: 0.123442	valid_0's l2: 0.0152379
# [278]	valid_0's rmse: 0.123252	valid_0's l2: 0.015191
# [279]	valid_0's rmse: 0.123106	valid_0's l2: 0.015155
# [280]	valid_0's rmse: 0.123015	valid_0's l2: 0.0151326
# [281]	valid_0's rmse: 0.122866	valid_0's l2: 0.0150961
# [282]	valid_0's rmse: 0.122699	valid_0's l2: 0.0150552
# [283]	valid_0's rmse: 0.122589	valid_0's l2: 0.0150281
# [284]	valid_0's rmse: 0.122452	valid_0's l2: 0.0149945
# [285]	valid_0's rmse: 0.122336	valid_0's l2: 0.0149661
# [286]	valid_0's rmse: 0.12219	valid_0's l2: 0.0149303
# [287]	valid_0's rmse: 0.122048	valid_0's l2: 0.0148958
# [288]	valid_0's rmse: 0.121909	valid_0's l2: 0.0148617
# [289]	valid_0's rmse: 0.121734	valid_0's l2: 0.0148191
# [290]	valid_0's rmse: 0.121577	valid_0's l2: 0.014781
# [291]	valid_0's rmse: 0.121434	valid_0's l2: 0.0147462
# [292]	valid_0's rmse: 0.121312	valid_0's l2: 0.0147165
# [293]	valid_0's rmse: 0.121171	valid_0's l2: 0.0146825
# [294]	valid_0's rmse: 0.12103	valid_0's l2: 0.0146484
# [295]	valid_0's rmse: 0.120888	valid_0's l2: 0.0146139
# [296]	valid_0's rmse: 0.120739	valid_0's l2: 0.0145778
# [297]	valid_0's rmse: 0.120643	valid_0's l2: 0.0145547
# [298]	valid_0's rmse: 0.120513	valid_0's l2: 0.0145233
# [299]	valid_0's rmse: 0.12037	valid_0's l2: 0.014489
# [300]	valid_0's rmse: 0.120274	valid_0's l2: 0.0144658
# [301]	valid_0's rmse: 0.120156	valid_0's l2: 0.0144374
# [302]	valid_0's rmse: 0.120006	valid_0's l2: 0.0144015
# [303]	valid_0's rmse: 0.119892	valid_0's l2: 0.014374
# [304]	valid_0's rmse: 0.119724	valid_0's l2: 0.0143339
# [305]	valid_0's rmse: 0.119638	valid_0's l2: 0.0143132
# [306]	valid_0's rmse: 0.119502	valid_0's l2: 0.0142808
# [307]	valid_0's rmse: 0.11942	valid_0's l2: 0.0142611
# [308]	valid_0's rmse: 0.119287	valid_0's l2: 0.0142294
# [309]	valid_0's rmse: 0.119147	valid_0's l2: 0.0141961
# [310]	valid_0's rmse: 0.119028	valid_0's l2: 0.0141676
# [311]	valid_0's rmse: 0.118947	valid_0's l2: 0.0141484
# [312]	valid_0's rmse: 0.118824	valid_0's l2: 0.0141192
# [313]	valid_0's rmse: 0.118734	valid_0's l2: 0.0140977
# [314]	valid_0's rmse: 0.118643	valid_0's l2: 0.0140761
# [315]	valid_0's rmse: 0.118539	valid_0's l2: 0.0140516
# [316]	valid_0's rmse: 0.118409	valid_0's l2: 0.0140207
# [317]	valid_0's rmse: 0.118357	valid_0's l2: 0.0140084
# [318]	valid_0's rmse: 0.11825	valid_0's l2: 0.013983
# [319]	valid_0's rmse: 0.118175	valid_0's l2: 0.0139654
# [320]	valid_0's rmse: 0.118126	valid_0's l2: 0.0139537
# [321]	valid_0's rmse: 0.117987	valid_0's l2: 0.013921
# [322]	valid_0's rmse: 0.117866	valid_0's l2: 0.0138925
# [323]	valid_0's rmse: 0.117733	valid_0's l2: 0.013861
# [324]	valid_0's rmse: 0.117659	valid_0's l2: 0.0138436
# [325]	valid_0's rmse: 0.117589	valid_0's l2: 0.0138272
# [326]	valid_0's rmse: 0.117515	valid_0's l2: 0.0138097
# [327]	valid_0's rmse: 0.117477	valid_0's l2: 0.0138009
# [328]	valid_0's rmse: 0.117343	valid_0's l2: 0.0137694
# [329]	valid_0's rmse: 0.117251	valid_0's l2: 0.0137478
# [330]	valid_0's rmse: 0.117169	valid_0's l2: 0.0137286
# [331]	valid_0's rmse: 0.117046	valid_0's l2: 0.0136997
# [332]	valid_0's rmse: 0.116972	valid_0's l2: 0.0136825
# [333]	valid_0's rmse: 0.116919	valid_0's l2: 0.0136699
# [334]	valid_0's rmse: 0.116842	valid_0's l2: 0.0136522
# [335]	valid_0's rmse: 0.116729	valid_0's l2: 0.0136256
# [336]	valid_0's rmse: 0.116642	valid_0's l2: 0.0136053
# [337]	valid_0's rmse: 0.116576	valid_0's l2: 0.01359
# [338]	valid_0's rmse: 0.1165	valid_0's l2: 0.0135723
# [339]	valid_0's rmse: 0.11638	valid_0's l2: 0.0135442
# [340]	valid_0's rmse: 0.116336	valid_0's l2: 0.0135342
# [341]	valid_0's rmse: 0.116208	valid_0's l2: 0.0135043
# [342]	valid_0's rmse: 0.116086	valid_0's l2: 0.013476
# [343]	valid_0's rmse: 0.116018	valid_0's l2: 0.0134603
# [344]	valid_0's rmse: 0.115954	valid_0's l2: 0.0134454
# [345]	valid_0's rmse: 0.115881	valid_0's l2: 0.0134285
# [346]	valid_0's rmse: 0.115841	valid_0's l2: 0.0134191
# [347]	valid_0's rmse: 0.115772	valid_0's l2: 0.0134031
# [348]	valid_0's rmse: 0.11576	valid_0's l2: 0.0134005
# [349]	valid_0's rmse: 0.115724	valid_0's l2: 0.0133919
# [350]	valid_0's rmse: 0.115683	valid_0's l2: 0.0133825
# [351]	valid_0's rmse: 0.115561	valid_0's l2: 0.0133543
# [352]	valid_0's rmse: 0.115508	valid_0's l2: 0.0133421
# [353]	valid_0's rmse: 0.115452	valid_0's l2: 0.0133292
# [354]	valid_0's rmse: 0.115396	valid_0's l2: 0.0133163
# [355]	valid_0's rmse: 0.115383	valid_0's l2: 0.0133133
# [356]	valid_0's rmse: 0.115292	valid_0's l2: 0.0132923
# [357]	valid_0's rmse: 0.115183	valid_0's l2: 0.0132671
# [358]	valid_0's rmse: 0.115117	valid_0's l2: 0.0132519
# [359]	valid_0's rmse: 0.115012	valid_0's l2: 0.0132278
# [360]	valid_0's rmse: 0.114975	valid_0's l2: 0.0132193
# [361]	valid_0's rmse: 0.114867	valid_0's l2: 0.0131944
# [362]	valid_0's rmse: 0.11476	valid_0's l2: 0.0131698
# [363]	valid_0's rmse: 0.114725	valid_0's l2: 0.0131618
# [364]	valid_0's rmse: 0.114654	valid_0's l2: 0.0131455
# [365]	valid_0's rmse: 0.114582	valid_0's l2: 0.0131291
# [366]	valid_0's rmse: 0.114531	valid_0's l2: 0.0131174
# [367]	valid_0's rmse: 0.114433	valid_0's l2: 0.0130949
# [368]	valid_0's rmse: 0.114364	valid_0's l2: 0.013079
# [369]	valid_0's rmse: 0.114336	valid_0's l2: 0.0130728
# [370]	valid_0's rmse: 0.114259	valid_0's l2: 0.013055
# [371]	valid_0's rmse: 0.114218	valid_0's l2: 0.0130459
# [372]	valid_0's rmse: 0.114217	valid_0's l2: 0.0130456
# [373]	valid_0's rmse: 0.114133	valid_0's l2: 0.0130263
# [374]	valid_0's rmse: 0.114079	valid_0's l2: 0.0130141
# [375]	valid_0's rmse: 0.114003	valid_0's l2: 0.0129966
# [376]	valid_0's rmse: 0.113923	valid_0's l2: 0.0129785
# [377]	valid_0's rmse: 0.113871	valid_0's l2: 0.0129667
# [378]	valid_0's rmse: 0.113758	valid_0's l2: 0.0129408
# [379]	valid_0's rmse: 0.113734	valid_0's l2: 0.0129354
# [380]	valid_0's rmse: 0.113741	valid_0's l2: 0.012937
# [381]	valid_0's rmse: 0.113673	valid_0's l2: 0.0129215
# [382]	valid_0's rmse: 0.113604	valid_0's l2: 0.0129058
# [383]	valid_0's rmse: 0.113542	valid_0's l2: 0.0128918
# [384]	valid_0's rmse: 0.113504	valid_0's l2: 0.0128832
# [385]	valid_0's rmse: 0.113476	valid_0's l2: 0.0128768
# [386]	valid_0's rmse: 0.113472	valid_0's l2: 0.0128759
# [387]	valid_0's rmse: 0.113413	valid_0's l2: 0.0128624
# [388]	valid_0's rmse: 0.113407	valid_0's l2: 0.0128612
# [389]	valid_0's rmse: 0.113374	valid_0's l2: 0.0128537
# [390]	valid_0's rmse: 0.113321	valid_0's l2: 0.0128417
# [391]	valid_0's rmse: 0.113264	valid_0's l2: 0.0128288
# [392]	valid_0's rmse: 0.113245	valid_0's l2: 0.0128244
# [393]	valid_0's rmse: 0.11317	valid_0's l2: 0.0128075
# [394]	valid_0's rmse: 0.113132	valid_0's l2: 0.0127989
# [395]	valid_0's rmse: 0.1131	valid_0's l2: 0.0127915
# [396]	valid_0's rmse: 0.113054	valid_0's l2: 0.0127812
# [397]	valid_0's rmse: 0.113011	valid_0's l2: 0.0127714
# [398]	valid_0's rmse: 0.112974	valid_0's l2: 0.012763
# [399]	valid_0's rmse: 0.112951	valid_0's l2: 0.012758
# [400]	valid_0's rmse: 0.112918	valid_0's l2: 0.0127504
# [401]	valid_0's rmse: 0.112869	valid_0's l2: 0.0127394
# [402]	valid_0's rmse: 0.112813	valid_0's l2: 0.0127269
# [403]	valid_0's rmse: 0.112774	valid_0's l2: 0.012718
# [404]	valid_0's rmse: 0.112716	valid_0's l2: 0.0127048
# [405]	valid_0's rmse: 0.112646	valid_0's l2: 0.0126891
# [406]	valid_0's rmse: 0.112564	valid_0's l2: 0.0126707
# [407]	valid_0's rmse: 0.112495	valid_0's l2: 0.0126551
# [408]	valid_0's rmse: 0.112418	valid_0's l2: 0.0126378
# [409]	valid_0's rmse: 0.112353	valid_0's l2: 0.0126232
# [410]	valid_0's rmse: 0.112299	valid_0's l2: 0.012611
# [411]	valid_0's rmse: 0.112284	valid_0's l2: 0.0126078
# [412]	valid_0's rmse: 0.112256	valid_0's l2: 0.0126013
# [413]	valid_0's rmse: 0.112203	valid_0's l2: 0.0125895
# [414]	valid_0's rmse: 0.112166	valid_0's l2: 0.0125812
# [415]	valid_0's rmse: 0.112117	valid_0's l2: 0.0125702
# [416]	valid_0's rmse: 0.112069	valid_0's l2: 0.0125596
# [417]	valid_0's rmse: 0.112038	valid_0's l2: 0.0125526
# [418]	valid_0's rmse: 0.112001	valid_0's l2: 0.0125443
# [419]	valid_0's rmse: 0.111955	valid_0's l2: 0.0125339
# [420]	valid_0's rmse: 0.111923	valid_0's l2: 0.0125268
# [421]	valid_0's rmse: 0.111918	valid_0's l2: 0.0125256
# [422]	valid_0's rmse: 0.111897	valid_0's l2: 0.0125209
# [423]	valid_0's rmse: 0.111885	valid_0's l2: 0.0125182
# [424]	valid_0's rmse: 0.111851	valid_0's l2: 0.0125106
# [425]	valid_0's rmse: 0.111794	valid_0's l2: 0.0124979
# [426]	valid_0's rmse: 0.11179	valid_0's l2: 0.0124971
# [427]	valid_0's rmse: 0.111785	valid_0's l2: 0.012496
# [428]	valid_0's rmse: 0.111762	valid_0's l2: 0.0124908
# [429]	valid_0's rmse: 0.111772	valid_0's l2: 0.0124929
# [430]	valid_0's rmse: 0.111746	valid_0's l2: 0.0124873
# [431]	valid_0's rmse: 0.1117	valid_0's l2: 0.012477
# [432]	valid_0's rmse: 0.111659	valid_0's l2: 0.0124678
# [433]	valid_0's rmse: 0.111619	valid_0's l2: 0.0124588
# [434]	valid_0's rmse: 0.111585	valid_0's l2: 0.0124512
# [435]	valid_0's rmse: 0.111559	valid_0's l2: 0.0124454
# [436]	valid_0's rmse: 0.111538	valid_0's l2: 0.0124408
# [437]	valid_0's rmse: 0.111499	valid_0's l2: 0.0124321
# [438]	valid_0's rmse: 0.111474	valid_0's l2: 0.0124266
# [439]	valid_0's rmse: 0.111413	valid_0's l2: 0.0124128
# [440]	valid_0's rmse: 0.111357	valid_0's l2: 0.0124003
# [441]	valid_0's rmse: 0.111311	valid_0's l2: 0.0123902
# [442]	valid_0's rmse: 0.11129	valid_0's l2: 0.0123855
# [443]	valid_0's rmse: 0.111249	valid_0's l2: 0.0123764
# [444]	valid_0's rmse: 0.111279	valid_0's l2: 0.0123831
# [445]	valid_0's rmse: 0.111231	valid_0's l2: 0.0123724
# [446]	valid_0's rmse: 0.111216	valid_0's l2: 0.0123689
# [447]	valid_0's rmse: 0.111161	valid_0's l2: 0.0123568
# [448]	valid_0's rmse: 0.111154	valid_0's l2: 0.0123552
# [449]	valid_0's rmse: 0.111112	valid_0's l2: 0.012346
# [450]	valid_0's rmse: 0.111115	valid_0's l2: 0.0123466
# [451]	valid_0's rmse: 0.111056	valid_0's l2: 0.0123334
# [452]	valid_0's rmse: 0.110976	valid_0's l2: 0.0123158
# [453]	valid_0's rmse: 0.110925	valid_0's l2: 0.0123044
# [454]	valid_0's rmse: 0.110922	valid_0's l2: 0.0123036
# [455]	valid_0's rmse: 0.110931	valid_0's l2: 0.0123057
# [456]	valid_0's rmse: 0.110902	valid_0's l2: 0.0122993
# [457]	valid_0's rmse: 0.110846	valid_0's l2: 0.0122869
# [458]	valid_0's rmse: 0.110826	valid_0's l2: 0.0122825
# [459]	valid_0's rmse: 0.110764	valid_0's l2: 0.0122686
# [460]	valid_0's rmse: 0.110736	valid_0's l2: 0.0122625
# [461]	valid_0's rmse: 0.110647	valid_0's l2: 0.0122427
# [462]	valid_0's rmse: 0.110622	valid_0's l2: 0.0122371
# [463]	valid_0's rmse: 0.110608	valid_0's l2: 0.0122341
# [464]	valid_0's rmse: 0.110574	valid_0's l2: 0.0122265
# [465]	valid_0's rmse: 0.110551	valid_0's l2: 0.0122216
# [466]	valid_0's rmse: 0.110527	valid_0's l2: 0.0122162
# [467]	valid_0's rmse: 0.110505	valid_0's l2: 0.0122114
# [468]	valid_0's rmse: 0.110428	valid_0's l2: 0.0121944
# [469]	valid_0's rmse: 0.110383	valid_0's l2: 0.0121845
# [470]	valid_0's rmse: 0.110353	valid_0's l2: 0.0121779
# [471]	valid_0's rmse: 0.110334	valid_0's l2: 0.0121737
# [472]	valid_0's rmse: 0.110319	valid_0's l2: 0.0121703
# [473]	valid_0's rmse: 0.110277	valid_0's l2: 0.012161
# [474]	valid_0's rmse: 0.110265	valid_0's l2: 0.0121584
# [475]	valid_0's rmse: 0.110258	valid_0's l2: 0.0121568
# [476]	valid_0's rmse: 0.110257	valid_0's l2: 0.0121565
# [477]	valid_0's rmse: 0.110268	valid_0's l2: 0.0121591
# [478]	valid_0's rmse: 0.110263	valid_0's l2: 0.012158
# [479]	valid_0's rmse: 0.110278	valid_0's l2: 0.0121613
# [480]	valid_0's rmse: 0.110271	valid_0's l2: 0.0121598
# [481]	valid_0's rmse: 0.110265	valid_0's l2: 0.0121583
# [482]	valid_0's rmse: 0.110246	valid_0's l2: 0.0121543
# [483]	valid_0's rmse: 0.110205	valid_0's l2: 0.0121451
# [484]	valid_0's rmse: 0.110206	valid_0's l2: 0.0121453
# [485]	valid_0's rmse: 0.11017	valid_0's l2: 0.0121374
# [486]	valid_0's rmse: 0.110125	valid_0's l2: 0.0121275
# [487]	valid_0's rmse: 0.110103	valid_0's l2: 0.0121226
# [488]	valid_0's rmse: 0.11007	valid_0's l2: 0.0121153
# [489]	valid_0's rmse: 0.110024	valid_0's l2: 0.0121053
# [490]	valid_0's rmse: 0.109995	valid_0's l2: 0.0120988
# [491]	valid_0's rmse: 0.109979	valid_0's l2: 0.0120954
# [492]	valid_0's rmse: 0.109956	valid_0's l2: 0.0120903
# [493]	valid_0's rmse: 0.109929	valid_0's l2: 0.0120844
# [494]	valid_0's rmse: 0.109879	valid_0's l2: 0.0120735
# [495]	valid_0's rmse: 0.109876	valid_0's l2: 0.0120728
# [496]	valid_0's rmse: 0.109877	valid_0's l2: 0.0120731
# [497]	valid_0's rmse: 0.109872	valid_0's l2: 0.0120718
# [498]	valid_0's rmse: 0.10984	valid_0's l2: 0.0120648
# [499]	valid_0's rmse: 0.109827	valid_0's l2: 0.0120619
# [500]	valid_0's rmse: 0.109795	valid_0's l2: 0.0120549
# [501]	valid_0's rmse: 0.109768	valid_0's l2: 0.0120489
# [502]	valid_0's rmse: 0.109746	valid_0's l2: 0.0120442
# [503]	valid_0's rmse: 0.109744	valid_0's l2: 0.0120437
# [504]	valid_0's rmse: 0.109718	valid_0's l2: 0.012038
# [505]	valid_0's rmse: 0.109725	valid_0's l2: 0.0120396
# [506]	valid_0's rmse: 0.109736	valid_0's l2: 0.0120421
# [507]	valid_0's rmse: 0.109723	valid_0's l2: 0.0120391
# [508]	valid_0's rmse: 0.10972	valid_0's l2: 0.0120384
# [509]	valid_0's rmse: 0.109705	valid_0's l2: 0.0120352
# [510]	valid_0's rmse: 0.109701	valid_0's l2: 0.0120343
# [511]	valid_0's rmse: 0.109671	valid_0's l2: 0.0120278
# [512]	valid_0's rmse: 0.109637	valid_0's l2: 0.0120202
# [513]	valid_0's rmse: 0.109628	valid_0's l2: 0.0120182
# [514]	valid_0's rmse: 0.10958	valid_0's l2: 0.0120077
# [515]	valid_0's rmse: 0.109548	valid_0's l2: 0.0120008
# [516]	valid_0's rmse: 0.109528	valid_0's l2: 0.0119963
# [517]	valid_0's rmse: 0.109503	valid_0's l2: 0.0119908
# [518]	valid_0's rmse: 0.109518	valid_0's l2: 0.0119943
# [519]	valid_0's rmse: 0.109445	valid_0's l2: 0.0119782
# [520]	valid_0's rmse: 0.109413	valid_0's l2: 0.0119712
# [521]	valid_0's rmse: 0.109432	valid_0's l2: 0.0119753
# [522]	valid_0's rmse: 0.10939	valid_0's l2: 0.0119661
# [523]	valid_0's rmse: 0.109413	valid_0's l2: 0.0119712
# [524]	valid_0's rmse: 0.109436	valid_0's l2: 0.0119763
# [525]	valid_0's rmse: 0.109433	valid_0's l2: 0.0119755
# [526]	valid_0's rmse: 0.109399	valid_0's l2: 0.011968
# [527]	valid_0's rmse: 0.109435	valid_0's l2: 0.0119761
# [528]	valid_0's rmse: 0.109419	valid_0's l2: 0.0119725
# [529]	valid_0's rmse: 0.109425	valid_0's l2: 0.0119739
# [530]	valid_0's rmse: 0.109403	valid_0's l2: 0.0119691
# [531]	valid_0's rmse: 0.10942	valid_0's l2: 0.0119728
# [532]	valid_0's rmse: 0.10942	valid_0's l2: 0.0119728
# [533]	valid_0's rmse: 0.109418	valid_0's l2: 0.0119723
# [534]	valid_0's rmse: 0.10939	valid_0's l2: 0.0119661
# [535]	valid_0's rmse: 0.109371	valid_0's l2: 0.011962
# [536]	valid_0's rmse: 0.109346	valid_0's l2: 0.0119566
# [537]	valid_0's rmse: 0.109322	valid_0's l2: 0.0119513
# [538]	valid_0's rmse: 0.109306	valid_0's l2: 0.0119479
# [539]	valid_0's rmse: 0.109271	valid_0's l2: 0.0119401
# [540]	valid_0's rmse: 0.109257	valid_0's l2: 0.0119371
# [541]	valid_0's rmse: 0.109197	valid_0's l2: 0.011924
# [542]	valid_0's rmse: 0.109186	valid_0's l2: 0.0119216
# [543]	valid_0's rmse: 0.109159	valid_0's l2: 0.0119156
# [544]	valid_0's rmse: 0.109161	valid_0's l2: 0.0119161
# [545]	valid_0's rmse: 0.109134	valid_0's l2: 0.0119103
# [546]	valid_0's rmse: 0.109128	valid_0's l2: 0.011909
# [547]	valid_0's rmse: 0.109136	valid_0's l2: 0.0119107
# [548]	valid_0's rmse: 0.109145	valid_0's l2: 0.0119126
# [549]	valid_0's rmse: 0.109114	valid_0's l2: 0.0119058
# [550]	valid_0's rmse: 0.109108	valid_0's l2: 0.0119045
# [551]	valid_0's rmse: 0.109098	valid_0's l2: 0.0119023
# [552]	valid_0's rmse: 0.109097	valid_0's l2: 0.0119023
# [553]	valid_0's rmse: 0.109092	valid_0's l2: 0.0119011
# [554]	valid_0's rmse: 0.109096	valid_0's l2: 0.0119019
# [555]	valid_0's rmse: 0.109082	valid_0's l2: 0.0118989
# [556]	valid_0's rmse: 0.10905	valid_0's l2: 0.0118919
# [557]	valid_0's rmse: 0.109039	valid_0's l2: 0.0118895
# [558]	valid_0's rmse: 0.10904	valid_0's l2: 0.0118897
# [559]	valid_0's rmse: 0.109038	valid_0's l2: 0.0118894
# [560]	valid_0's rmse: 0.109025	valid_0's l2: 0.0118864
# [561]	valid_0's rmse: 0.109044	valid_0's l2: 0.0118905
# [562]	valid_0's rmse: 0.109019	valid_0's l2: 0.0118852
# [563]	valid_0's rmse: 0.10902	valid_0's l2: 0.0118854
# [564]	valid_0's rmse: 0.109002	valid_0's l2: 0.0118814
# [565]	valid_0's rmse: 0.109	valid_0's l2: 0.0118809
# [566]	valid_0's rmse: 0.109004	valid_0's l2: 0.0118818
# [567]	valid_0's rmse: 0.109016	valid_0's l2: 0.0118846
# [568]	valid_0's rmse: 0.109	valid_0's l2: 0.0118811
# [569]	valid_0's rmse: 0.109016	valid_0's l2: 0.0118844
# [570]	valid_0's rmse: 0.109027	valid_0's l2: 0.0118868
# [571]	valid_0's rmse: 0.108992	valid_0's l2: 0.0118793
# [572]	valid_0's rmse: 0.109006	valid_0's l2: 0.0118822
# [573]	valid_0's rmse: 0.108991	valid_0's l2: 0.011879
# [574]	valid_0's rmse: 0.109008	valid_0's l2: 0.0118827
# [575]	valid_0's rmse: 0.109008	valid_0's l2: 0.0118827
# [576]	valid_0's rmse: 0.109008	valid_0's l2: 0.0118828
# [577]	valid_0's rmse: 0.108998	valid_0's l2: 0.0118807
# [578]	valid_0's rmse: 0.109006	valid_0's l2: 0.0118823
# [579]	valid_0's rmse: 0.108978	valid_0's l2: 0.0118763
# [580]	valid_0's rmse: 0.109009	valid_0's l2: 0.0118829
# [581]	valid_0's rmse: 0.109005	valid_0's l2: 0.0118821
# [582]	valid_0's rmse: 0.10901	valid_0's l2: 0.0118833
# [583]	valid_0's rmse: 0.108972	valid_0's l2: 0.011875
# [584]	valid_0's rmse: 0.108978	valid_0's l2: 0.0118763
# [585]	valid_0's rmse: 0.108985	valid_0's l2: 0.0118776
# [586]	valid_0's rmse: 0.108987	valid_0's l2: 0.0118781
# [587]	valid_0's rmse: 0.108947	valid_0's l2: 0.0118694
# [588]	valid_0's rmse: 0.108902	valid_0's l2: 0.0118597
# [589]	valid_0's rmse: 0.108904	valid_0's l2: 0.0118601
# [590]	valid_0's rmse: 0.10892	valid_0's l2: 0.0118635
# [591]	valid_0's rmse: 0.108907	valid_0's l2: 0.0118607
# [592]	valid_0's rmse: 0.108882	valid_0's l2: 0.0118552
# [593]	valid_0's rmse: 0.108904	valid_0's l2: 0.0118602
# [594]	valid_0's rmse: 0.108895	valid_0's l2: 0.0118581
# [595]	valid_0's rmse: 0.108911	valid_0's l2: 0.0118616
# [596]	valid_0's rmse: 0.108895	valid_0's l2: 0.011858
# [597]	valid_0's rmse: 0.108875	valid_0's l2: 0.0118538
# [598]	valid_0's rmse: 0.108856	valid_0's l2: 0.0118496
# [599]	valid_0's rmse: 0.108865	valid_0's l2: 0.0118515
# [600]	valid_0's rmse: 0.10889	valid_0's l2: 0.011857
# [601]	valid_0's rmse: 0.10889	valid_0's l2: 0.0118571
# [602]	valid_0's rmse: 0.10887	valid_0's l2: 0.0118527
# [603]	valid_0's rmse: 0.108861	valid_0's l2: 0.0118508
# [604]	valid_0's rmse: 0.108845	valid_0's l2: 0.0118473
# [605]	valid_0's rmse: 0.108857	valid_0's l2: 0.0118498
# [606]	valid_0's rmse: 0.108838	valid_0's l2: 0.0118456
# [607]	valid_0's rmse: 0.108824	valid_0's l2: 0.0118427
# [608]	valid_0's rmse: 0.108814	valid_0's l2: 0.0118405
# [609]	valid_0's rmse: 0.108817	valid_0's l2: 0.0118411
# [610]	valid_0's rmse: 0.108797	valid_0's l2: 0.0118368
# [611]	valid_0's rmse: 0.108786	valid_0's l2: 0.0118344
# [612]	valid_0's rmse: 0.108786	valid_0's l2: 0.0118343
# [613]	valid_0's rmse: 0.108763	valid_0's l2: 0.0118295
# [614]	valid_0's rmse: 0.108762	valid_0's l2: 0.0118292
# [615]	valid_0's rmse: 0.108766	valid_0's l2: 0.01183
# [616]	valid_0's rmse: 0.108778	valid_0's l2: 0.0118327
# [617]	valid_0's rmse: 0.108763	valid_0's l2: 0.0118295
# [618]	valid_0's rmse: 0.108748	valid_0's l2: 0.0118261
# [619]	valid_0's rmse: 0.108754	valid_0's l2: 0.0118275
# [620]	valid_0's rmse: 0.108741	valid_0's l2: 0.0118245
# [621]	valid_0's rmse: 0.108753	valid_0's l2: 0.0118272
# [622]	valid_0's rmse: 0.108743	valid_0's l2: 0.011825
# [623]	valid_0's rmse: 0.108752	valid_0's l2: 0.011827
# [624]	valid_0's rmse: 0.108742	valid_0's l2: 0.0118248
# [625]	valid_0's rmse: 0.108757	valid_0's l2: 0.0118282
# [626]	valid_0's rmse: 0.108752	valid_0's l2: 0.0118271
# [627]	valid_0's rmse: 0.108762	valid_0's l2: 0.0118292
# [628]	valid_0's rmse: 0.108778	valid_0's l2: 0.0118327
# [629]	valid_0's rmse: 0.108791	valid_0's l2: 0.0118355
# [630]	valid_0's rmse: 0.108809	valid_0's l2: 0.0118394
# [631]	valid_0's rmse: 0.108853	valid_0's l2: 0.0118489
# [632]	valid_0's rmse: 0.108855	valid_0's l2: 0.0118494
# [633]	valid_0's rmse: 0.108867	valid_0's l2: 0.0118521
# [634]	valid_0's rmse: 0.108836	valid_0's l2: 0.0118453
# [635]	valid_0's rmse: 0.108845	valid_0's l2: 0.0118473
# [636]	valid_0's rmse: 0.108862	valid_0's l2: 0.0118509
# [637]	valid_0's rmse: 0.10886	valid_0's l2: 0.0118504
# [638]	valid_0's rmse: 0.108895	valid_0's l2: 0.011858
# [639]	valid_0's rmse: 0.108917	valid_0's l2: 0.0118628
# [640]	valid_0's rmse: 0.108942	valid_0's l2: 0.0118685
# [641]	valid_0's rmse: 0.108942	valid_0's l2: 0.0118683
# [642]	valid_0's rmse: 0.108945	valid_0's l2: 0.0118689
# [643]	valid_0's rmse: 0.108924	valid_0's l2: 0.0118644
# [644]	valid_0's rmse: 0.108933	valid_0's l2: 0.0118664
# [645]	valid_0's rmse: 0.108925	valid_0's l2: 0.0118646
# [646]	valid_0's rmse: 0.108956	valid_0's l2: 0.0118714
# [647]	valid_0's rmse: 0.108942	valid_0's l2: 0.0118684
# [648]	valid_0's rmse: 0.108954	valid_0's l2: 0.011871
# [649]	valid_0's rmse: 0.108949	valid_0's l2: 0.0118699
# [650]	valid_0's rmse: 0.108952	valid_0's l2: 0.0118706
# [651]	valid_0's rmse: 0.108941	valid_0's l2: 0.0118681
# [652]	valid_0's rmse: 0.108937	valid_0's l2: 0.0118672
# [653]	valid_0's rmse: 0.108931	valid_0's l2: 0.011866
# [654]	valid_0's rmse: 0.108978	valid_0's l2: 0.0118762
# [655]	valid_0's rmse: 0.108985	valid_0's l2: 0.0118777
# [656]	valid_0's rmse: 0.109014	valid_0's l2: 0.0118841
# [657]	valid_0's rmse: 0.109008	valid_0's l2: 0.0118827
# [658]	valid_0's rmse: 0.109003	valid_0's l2: 0.0118818
# [659]	valid_0's rmse: 0.108978	valid_0's l2: 0.0118763
# [660]	valid_0's rmse: 0.10897	valid_0's l2: 0.0118746
# [661]	valid_0's rmse: 0.108981	valid_0's l2: 0.0118769
# [662]	valid_0's rmse: 0.108984	valid_0's l2: 0.0118774
# [663]	valid_0's rmse: 0.108954	valid_0's l2: 0.011871
# [664]	valid_0's rmse: 0.108939	valid_0's l2: 0.0118676
# [665]	valid_0's rmse: 0.108936	valid_0's l2: 0.0118672
# [666]	valid_0's rmse: 0.108953	valid_0's l2: 0.0118708
# [667]	valid_0's rmse: 0.108964	valid_0's l2: 0.0118731
# [668]	valid_0's rmse: 0.108968	valid_0's l2: 0.011874
# [669]	valid_0's rmse: 0.108975	valid_0's l2: 0.0118755
# [670]	valid_0's rmse: 0.108993	valid_0's l2: 0.0118794
# [671]	valid_0's rmse: 0.109039	valid_0's l2: 0.0118894
# [672]	valid_0's rmse: 0.10908	valid_0's l2: 0.0118985
# [673]	valid_0's rmse: 0.109095	valid_0's l2: 0.0119018
# [674]	valid_0's rmse: 0.109157	valid_0's l2: 0.0119152
# [675]	valid_0's rmse: 0.109161	valid_0's l2: 0.0119162
# [676]	valid_0's rmse: 0.109164	valid_0's l2: 0.0119168
# [677]	valid_0's rmse: 0.109185	valid_0's l2: 0.0119214
# [678]	valid_0's rmse: 0.109183	valid_0's l2: 0.011921
# [679]	valid_0's rmse: 0.109205	valid_0's l2: 0.0119257
# [680]	valid_0's rmse: 0.109193	valid_0's l2: 0.0119231
# [681]	valid_0's rmse: 0.109193	valid_0's l2: 0.011923
# [682]	valid_0's rmse: 0.109187	valid_0's l2: 0.0119218
# [683]	valid_0's rmse: 0.109165	valid_0's l2: 0.0119171
# [684]	valid_0's rmse: 0.109178	valid_0's l2: 0.0119198
# [685]	valid_0's rmse: 0.109195	valid_0's l2: 0.0119235
# [686]	valid_0's rmse: 0.109191	valid_0's l2: 0.0119227
# [687]	valid_0's rmse: 0.109179	valid_0's l2: 0.0119201
# [688]	valid_0's rmse: 0.109192	valid_0's l2: 0.011923
# [689]	valid_0's rmse: 0.109197	valid_0's l2: 0.0119241
# [690]	valid_0's rmse: 0.109199	valid_0's l2: 0.0119244
# [691]	valid_0's rmse: 0.109201	valid_0's l2: 0.011925
# [692]	valid_0's rmse: 0.109217	valid_0's l2: 0.0119284
# [693]	valid_0's rmse: 0.109216	valid_0's l2: 0.0119282
# [694]	valid_0's rmse: 0.109203	valid_0's l2: 0.0119254
# [695]	valid_0's rmse: 0.109194	valid_0's l2: 0.0119233
# [696]	valid_0's rmse: 0.109187	valid_0's l2: 0.0119217
# [697]	valid_0's rmse: 0.109155	valid_0's l2: 0.0119148
# [698]	valid_0's rmse: 0.109157	valid_0's l2: 0.0119153
# [699]	valid_0's rmse: 0.109177	valid_0's l2: 0.0119196
# [700]	valid_0's rmse: 0.109202	valid_0's l2: 0.0119251
# [701]	valid_0's rmse: 0.109197	valid_0's l2: 0.0119241
# [702]	valid_0's rmse: 0.109207	valid_0's l2: 0.0119263
# [703]	valid_0's rmse: 0.10922	valid_0's l2: 0.011929
# [704]	valid_0's rmse: 0.109245	valid_0's l2: 0.0119344
# [705]	valid_0's rmse: 0.109268	valid_0's l2: 0.0119395
# [706]	valid_0's rmse: 0.109281	valid_0's l2: 0.0119424
# [707]	valid_0's rmse: 0.109294	valid_0's l2: 0.0119452
# [708]	valid_0's rmse: 0.109323	valid_0's l2: 0.0119515
# [709]	valid_0's rmse: 0.109328	valid_0's l2: 0.0119527
# [710]	valid_0's rmse: 0.109317	valid_0's l2: 0.0119502
# [711]	valid_0's rmse: 0.109323	valid_0's l2: 0.0119515
# [712]	valid_0's rmse: 0.109279	valid_0's l2: 0.0119419
# [713]	valid_0's rmse: 0.109242	valid_0's l2: 0.0119339
# [714]	valid_0's rmse: 0.109241	valid_0's l2: 0.0119336
# [715]	valid_0's rmse: 0.109218	valid_0's l2: 0.0119286
# [716]	valid_0's rmse: 0.109198	valid_0's l2: 0.0119242
# [717]	valid_0's rmse: 0.109197	valid_0's l2: 0.0119241
# [718]	valid_0's rmse: 0.109188	valid_0's l2: 0.0119219
# [719]	valid_0's rmse: 0.109179	valid_0's l2: 0.01192
# [720]	valid_0's rmse: 0.109202	valid_0's l2: 0.011925
# Early stopping, best iteration is:
# [620]	valid_0's rmse: 0.108741	valid_0's l2: 0.0118245
# Duration: 0.9225242137908936s

# %%
# Plot feature importance
figsize=(40,40)
fig, ax = plt.subplots(1,1,figsize=figsize)
plot_importance(model, ax=ax,height = 1)

# %%
# predict sales in validation dataset
val_predictions = model.predict(X_val).flatten()

# scatter plot of True vs Predicted values
plt.scatter(y_val, val_predictions)
plt.xlabel('True Values $')
plt.ylabel('Predictions $')
plt.axis('equal')
plt.axis('square')
plt.xlim([10,plt.xlim()[1]])
plt.ylim([10,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])

# %%
# Histogram of error values
error = val_predictions - y_val
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error $")
_ = plt.ylabel("Count")

# %% [markdown]
# # Submission

# %%
# predict sales for test dataset
predictions = model.predict(X_test[X_train.columns]) # keep columns in same order
# reverse log1p, and round results
predictions = np.round(np.exp(predictions)-1)
print(predictions)
# Out:
# [124976. 164728. 183773. ... 169465. 117424. 228574.]

# %%
# prepare dataframe to submit
submission = pd.DataFrame({'Id': df_test.index, 'SalePrice': predictions})
submission.head()
# Out:
#      Id  SalePrice
# 0  1461   124976.0
# 1  1462   164728.0
# 2  1463   183773.0
# 3  1464   194574.0
# 4  1465   186951.0

# %%
# submit
t_stamp = str(datetime.datetime.now())
t1 = t_stamp.split(" ")[0]
t2 = t_stamp.split(" ")[1].split(".")[0]
submission.to_csv('lgbm2_{}_{}_{}.csv'.format(t1, t2, round(results_rmsle.mean(),5)), index=False)
